# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport

# %% [markdown]
# # -------------------------------------------------------------------------------------

# %% [markdown]
# # CREDIT DATA TUTORIAL

# %% [markdown]
# # -----------------------------------------------------------------------------------

# %%
credit = pd.read_csv('DefaultCreditCardClients.csv')

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %% [markdown]
# ##### Understand the summary of data

# %%
credit.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  30000.000000    30000.000000  30000.000000  30000.000000  30000.000000
# mean   15000.500000   167484.322667      1.603733      1.853133      1.551867
# std     8660.398374   129747.661567      0.489129      0.790349      0.521970
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     7500.750000    50000.000000      1.000000      1.000000      1.000000
# 50%    15000.500000   140000.000000      2.000000      2.000000      2.000000
# 75%    22500.250000   240000.000000      2.000000      2.000000      2.000000
# max    30000.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      35.485500     -0.016700     -0.133767     -0.166200     -0.220667
# std        9.217904      1.123802      1.197186      1.196868      1.169139
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %% [markdown]
#  ##### Check the data types of each variable

# %%
credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 25 columns):
# ID                            30000 non-null int64
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# BILL_AMT6                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(25)
# memory usage: 5.7 MB

# %%
credit.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...          0          0          0         0       689         0
# 1  ...       3272       3455       3261         0      1000      1000
# 2  ...      14331      14948      15549      1518      1500      1000
# 3  ...      28314      28959      29547      2000      2019      1200
# 4  ...      20940      19146      19131      2000     36681     10000
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         0         0         0                           1
# 1      1000         0      2000                           1
# 2      1000      1000      5000                           0
# 3      1100      1069      1000                           0
# 4      9000       689       679                           0
#
# [5 rows x 25 columns]

# %%
credit.tail()
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 29995  29996     220000    1          3         1   39      0      0      0
# 29996  29997     150000    1          3         2   43     -1     -1     -1
# 29997  29998      30000    1          2         2   37      4      3      2
# 29998  29999      80000    1          3         1   41      1     -1      0
# 29999  30000      50000    1          2         1   46      0      0      0
#
#        PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996     -1  ...       8979       5190          0      1837      3526
# 29997     -1  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [5 rows x 25 columns]

# %%
print(credit['SEX'].describe())
# Out:
# count    30000.000000
# mean         1.603733
# std          0.489129
# min          1.000000
# 25%          1.000000
# 50%          2.000000
# 75%          2.000000
# max          2.000000
# Name: SEX, dtype: float64

# %% [markdown]
# ##### Data transformation - Check any missing data in dataframe

# %%
credit.isnull().values.any()
# Out:
# False

# %%
credit.isnull().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# dtype: int64

# %%
credit.isnull()
# Out:
#           ID  LIMIT_BAL    SEX  EDUCATION  MARRIAGE    AGE  PAY_0  PAY_2  \
# 0      False      False  False      False     False  False  False  False
# 1      False      False  False      False     False  False  False  False
# 2      False      False  False      False     False  False  False  False
# 3      False      False  False      False     False  False  False  False
# 4      False      False  False      False     False  False  False  False
# ...      ...        ...    ...        ...       ...    ...    ...    ...
# 29995  False      False  False      False     False  False  False  False
# 29996  False      False  False      False     False  False  False  False
# 29997  False      False  False      False     False  False  False  False
# 29998  False      False  False      False     False  False  False  False
# 29999  False      False  False      False     False  False  False  False
#
#        PAY_3  PAY_4  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0      False  False  ...      False      False      False     False     False
# 1      False  False  ...      False      False      False     False     False
# 2      False  False  ...      False      False      False     False     False
# 3      False  False  ...      False      False      False     False     False
# 4      False  False  ...      False      False      False     False     False
# ...      ...    ...  ...        ...        ...        ...       ...       ...
# 29995  False  False  ...      False      False      False     False     False
# 29996  False  False  ...      False      False      False     False     False
# 29997  False  False  ...      False      False      False     False     False
# 29998  False  False  ...      False      False      False     False     False
# 29999  False  False  ...      False      False      False     False     False
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0         False     False     False     False                       False
# 1         False     False     False     False                       False
# 2         False     False     False     False                       False
# 3         False     False     False     False                       False
# 4         False     False     False     False                       False
# ...         ...       ...       ...       ...                         ...
# 29995     False     False     False     False                       False
# 29996     False     False     False     False                       False
# 29997     False     False     False     False                       False
# 29998     False     False     False     False                       False
# 29999     False     False     False     False                       False
#
# [30000 rows x 25 columns]

# %% [markdown]
# ##### Data reduction - Drop "ID" column from dataframe

# %%
credit = credit.drop("ID", axis = 1)

# %%
credit.info
# Out:
# <bound method DataFrame.info of        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# 0         -2  ...          0          0          0         0       689
# 1          0  ...       3272       3455       3261         0      1000
# 2          0  ...      14331      14948      15549      1518      1500
# 3          0  ...      28314      28959      29547      2000      2019
# 4          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29995      0  ...      88004      31237      15980      8500     20000
# 29996      0  ...       8979       5190          0      1837      3526
# 29997      0  ...      20878      20582      19357         0         0
# 29998      0  ...      52774      11855      48944     85900      3409
# 29999      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# 0             0         0         0         0                           1
# 1          1000      1000         0      2000                           1
# 2          1000      1000      1000      5000                           0
# 3          1200      1100      1069      1000                           0
# 4         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29995      5003      3047      5000      1000                           0
# 29996      8998       129         0         0                           0
# 29997     22000      4200      2000      3100                           1
# 29998      1178      1926     52964      1804                           1
# 29999      1430      1000      1000      1000                           1
#
# [30000 rows x 24 columns]>

# %% [markdown]
# ##### Data discretization

# %% [markdown]
# ###### Age grouping

# %%
credit['age_bins'] = pd.cut(x=credit['AGE'], bins=[20,29,39,49,59,69,79])

# %%
credit
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0         -2  ...          0          0         0       689         0
# 1          0  ...       3455       3261         0      1000      1000
# 2          0  ...      14948      15549      1518      1500      1000
# 3          0  ...      28959      29547      2000      2019      1200
# 4          0  ...      19146      19131      2000     36681     10000
# ...      ...  ...        ...        ...       ...       ...       ...
# 29995      0  ...      31237      15980      8500     20000      5003
# 29996      0  ...       5190          0      1837      3526      8998
# 29997      0  ...      20582      19357         0         0     22000
# 29998      0  ...      11855      48944     85900      3409      1178
# 29999      0  ...      32428      15313      2078      1800      1430
#
#        PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month  age_bins
# 0             0         0         0                           1  (20, 29]
# 1          1000         0      2000                           1  (20, 29]
# 2          1000      1000      5000                           0  (29, 39]
# 3          1100      1069      1000                           0  (29, 39]
# 4          9000       689       679                           0  (49, 59]
# ...         ...       ...       ...                         ...       ...
# 29995      3047      5000      1000                           0  (29, 39]
# 29996       129         0         0                           0  (39, 49]
# 29997      4200      2000      3100                           1  (29, 39]
# 29998      1926     52964      1804                           1  (39, 49]
# 29999      1000      1000      1000                           1  (39, 49]
#
# [30000 rows x 25 columns]

# %%
credit['age_by_decade']=pd.cut(x=credit['AGE'], bins=[20,29,39,49,59,69,79], labels=['20','30','40','50','60','70'])

# %%
credit
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0         -2  ...          0         0       689         0         0
# 1          0  ...       3261         0      1000      1000      1000
# 2          0  ...      15549      1518      1500      1000      1000
# 3          0  ...      29547      2000      2019      1200      1100
# 4          0  ...      19131      2000     36681     10000      9000
# ...      ...  ...        ...       ...       ...       ...       ...
# 29995      0  ...      15980      8500     20000      5003      3047
# 29996      0  ...          0      1837      3526      8998       129
# 29997      0  ...      19357         0         0     22000      4200
# 29998      0  ...      48944     85900      3409      1178      1926
# 29999      0  ...      15313      2078      1800      1430      1000
#
#        PAY_AMT5  PAY_AMT6  default payment next month  age_bins  age_by_decade
# 0             0         0                           1  (20, 29]             20
# 1             0      2000                           1  (20, 29]             20
# 2          1000      5000                           0  (29, 39]             30
# 3          1069      1000                           0  (29, 39]             30
# 4           689       679                           0  (49, 59]             50
# ...         ...       ...                         ...       ...            ...
# 29995      5000      1000                           0  (29, 39]             30
# 29996         0         0                           0  (39, 49]             40
# 29997      2000      3100                           1  (29, 39]             30
# 29998     52964      1804                           1  (39, 49]             40
# 29999      1000      1000                           1  (39, 49]             40
#
# [30000 rows x 26 columns]

# %% [markdown]
# ##### Limit Balance Grouping

# %%
credit['limit_bins'] = pd.cut(x=credit['LIMIT_BAL'], bins=[9999,199999,299999,399999,499999,599999,699999,799999,899999,999999,1999999])

# %%
credit
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0         -2  ...         0       689         0         0         0         0
# 1          0  ...         0      1000      1000      1000         0      2000
# 2          0  ...      1518      1500      1000      1000      1000      5000
# 3          0  ...      2000      2019      1200      1100      1069      1000
# 4          0  ...      2000     36681     10000      9000       689       679
# ...      ...  ...       ...       ...       ...       ...       ...       ...
# 29995      0  ...      8500     20000      5003      3047      5000      1000
# 29996      0  ...      1837      3526      8998       129         0         0
# 29997      0  ...         0         0     22000      4200      2000      3100
# 29998      0  ...     85900      3409      1178      1926     52964      1804
# 29999      0  ...      2078      1800      1430      1000      1000      1000
#
#        default payment next month  age_bins  age_by_decade        limit_bins
# 0                               1  (20, 29]             20    (9999, 199999]
# 1                               1  (20, 29]             20    (9999, 199999]
# 2                               0  (29, 39]             30    (9999, 199999]
# 3                               0  (29, 39]             30    (9999, 199999]
# 4                               0  (49, 59]             50    (9999, 199999]
# ...                           ...       ...            ...               ...
# 29995                           0  (29, 39]             30  (199999, 299999]
# 29996                           0  (39, 49]             40    (9999, 199999]
# 29997                           1  (29, 39]             30    (9999, 199999]
# 29998                           1  (39, 49]             40    (9999, 199999]
# 29999                           1  (39, 49]             40    (9999, 199999]
#
# [30000 rows x 27 columns]

# %%
credit['limit_bal_gp']=pd.cut(x=credit['LIMIT_BAL'], bins=[9999,199999,299999,399999,499999,599999,699999,799999,899999,999999,1999999], labels=['10000','200000','300000','400000','500000','600000','700000','800000','900000','1000000'])

# %%
credit
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0         -2  ...       689         0         0         0         0
# 1          0  ...      1000      1000      1000         0      2000
# 2          0  ...      1500      1000      1000      1000      5000
# 3          0  ...      2019      1200      1100      1069      1000
# 4          0  ...     36681     10000      9000       689       679
# ...      ...  ...       ...       ...       ...       ...       ...
# 29995      0  ...     20000      5003      3047      5000      1000
# 29996      0  ...      3526      8998       129         0         0
# 29997      0  ...         0     22000      4200      2000      3100
# 29998      0  ...      3409      1178      1926     52964      1804
# 29999      0  ...      1800      1430      1000      1000      1000
#
#        default payment next month  age_bins  age_by_decade        limit_bins  \
# 0                               1  (20, 29]             20    (9999, 199999]
# 1                               1  (20, 29]             20    (9999, 199999]
# 2                               0  (29, 39]             30    (9999, 199999]
# 3                               0  (29, 39]             30    (9999, 199999]
# 4                               0  (49, 59]             50    (9999, 199999]
# ...                           ...       ...            ...               ...
# 29995                           0  (29, 39]             30  (199999, 299999]
# 29996                           0  (39, 49]             40    (9999, 199999]
# 29997                           1  (29, 39]             30    (9999, 199999]
# 29998                           1  (39, 49]             40    (9999, 199999]
# 29999                           1  (39, 49]             40    (9999, 199999]
#
#        limit_bal_gp
# 0             10000
# 1             10000
# 2             10000
# 3             10000
# 4             10000
# ...             ...
# 29995        200000
# 29996         10000
# 29997         10000
# 29998         10000
# 29999         10000
#
# [30000 rows x 28 columns]

# %% [markdown]
# ##### saving a new dataframe

# %%
credit.to_csv(r'C:\Users\User\Desktop\new_credit.csv', index=False)

# %% [markdown]
# ##### Visualizing the data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Showing column names in dataframe

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'age_bins', 'age_by_decade', 'limit_bins',
#        'limit_bal_gp'],
#       dtype='object')

# %% [markdown]
# ##### Histogram

# %%
plt.hist(credit['LIMIT_BAL'])
plt.show()

# %%
plt.hist(credit['LIMIT_BAL'], bins=5)
# Out:
# (array([2.0378e+04, 7.8180e+03, 1.7250e+03, 7.8000e+01, 1.0000e+00]),
#  array([  10000.,  208000.,  406000.,  604000.,  802000., 1000000.]),
#  <a list of 5 Patch objects>)

# %% [markdown]
# ##### Line plot

# %%
plt.plot(credit['LIMIT_BAL'])

# %% [markdown]
# ##### Scattor plot

# %%
x = credit['PAY_0']
y = credit['PAY_2']

# %%
plt.scatter(x,y)

# %% [markdown]
# ##### Box plot

# %%
header = credit.dtypes.index
print(header)
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default payment next month', 'age_bins', 'age_by_decade', 'limit_bins',
#        'limit_bal_gp'],
#       dtype='object')

# %%
A = credit['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %% [markdown]
# ##### Correlation

# %%
corrMat = credit.corr()

# %%
print(corrMat)
# Out:
#                             LIMIT_BAL       SEX  EDUCATION  MARRIAGE  \
# LIMIT_BAL                    1.000000  0.024755  -0.219161 -0.108139
# SEX                          0.024755  1.000000   0.014232 -0.031389
# EDUCATION                   -0.219161  0.014232   1.000000 -0.143464
# MARRIAGE                    -0.108139 -0.031389  -0.143464  1.000000
# AGE                          0.144713 -0.090874   0.175061 -0.414170
# PAY_0                       -0.271214 -0.057643   0.105364  0.019917
# PAY_2                       -0.296382 -0.070771   0.121566  0.024199
# PAY_3                       -0.286123 -0.066096   0.114025  0.032688
# PAY_4                       -0.267460 -0.060173   0.108793  0.033122
# PAY_5                       -0.249411 -0.055064   0.097520  0.035629
# PAY_6                       -0.235195 -0.044008   0.082316  0.034345
# BILL_AMT1                    0.285430 -0.033642   0.023581 -0.023472
# BILL_AMT2                    0.278314 -0.031183   0.018749 -0.021602
# BILL_AMT3                    0.283236 -0.024563   0.013002 -0.024909
# BILL_AMT4                    0.293988 -0.021880  -0.000451 -0.023344
# BILL_AMT5                    0.295562 -0.017005  -0.007567 -0.025393
# BILL_AMT6                    0.290389 -0.016733  -0.009099 -0.021207
# PAY_AMT1                     0.195236 -0.000242  -0.037456 -0.005979
# PAY_AMT2                     0.178408 -0.001391  -0.030038 -0.008093
# PAY_AMT3                     0.210167 -0.008597  -0.039943 -0.003541
# PAY_AMT4                     0.203242 -0.002229  -0.038218 -0.012659
# PAY_AMT5                     0.217202 -0.001667  -0.040358 -0.001205
# PAY_AMT6                     0.219595 -0.002766  -0.037200 -0.006641
# default payment next month  -0.153520 -0.039961   0.028006 -0.024339
#
#                                  AGE     PAY_0     PAY_2     PAY_3     PAY_4  \
# LIMIT_BAL                   0.144713 -0.271214 -0.296382 -0.286123 -0.267460
# SEX                        -0.090874 -0.057643 -0.070771 -0.066096 -0.060173
# EDUCATION                   0.175061  0.105364  0.121566  0.114025  0.108793
# MARRIAGE                   -0.414170  0.019917  0.024199  0.032688  0.033122
# AGE                         1.000000 -0.039447 -0.050148 -0.053048 -0.049722
# PAY_0                      -0.039447  1.000000  0.672164  0.574245  0.538841
# PAY_2                      -0.050148  0.672164  1.000000  0.766552  0.662067
# PAY_3                      -0.053048  0.574245  0.766552  1.000000  0.777359
# PAY_4                      -0.049722  0.538841  0.662067  0.777359  1.000000
# PAY_5                      -0.053826  0.509426  0.622780  0.686775  0.819835
# PAY_6                      -0.048773  0.474553  0.575501  0.632684  0.716449
# BILL_AMT1                   0.056239  0.187068  0.234887  0.208473  0.202812
# BILL_AMT2                   0.054283  0.189859  0.235257  0.237295  0.225816
# BILL_AMT3                   0.053710  0.179785  0.224146  0.227494  0.244983
# BILL_AMT4                   0.051353  0.179125  0.222237  0.227202  0.245917
# BILL_AMT5                   0.049345  0.180635  0.221348  0.225145  0.242902
# BILL_AMT6                   0.047613  0.176980  0.219403  0.222327  0.239154
# PAY_AMT1                    0.026147 -0.079269 -0.080701  0.001295 -0.009362
# PAY_AMT2                    0.021785 -0.070101 -0.058990 -0.066793 -0.001944
# PAY_AMT3                    0.029247 -0.070561 -0.055901 -0.053311 -0.069235
# PAY_AMT4                    0.021379 -0.064005 -0.046858 -0.046067 -0.043461
# PAY_AMT5                    0.022850 -0.058190 -0.037093 -0.035863 -0.033590
# PAY_AMT6                    0.019478 -0.058673 -0.036500 -0.035861 -0.026565
# default payment next month  0.013890  0.324794  0.263551  0.235253  0.216614
#
#                                PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  \
# LIMIT_BAL                  -0.249411  ...   0.293988   0.295562   0.290389
# SEX                        -0.055064  ...  -0.021880  -0.017005  -0.016733
# EDUCATION                   0.097520  ...  -0.000451  -0.007567  -0.009099
# MARRIAGE                    0.035629  ...  -0.023344  -0.025393  -0.021207
# AGE                        -0.053826  ...   0.051353   0.049345   0.047613
# PAY_0                       0.509426  ...   0.179125   0.180635   0.176980
# PAY_2                       0.622780  ...   0.222237   0.221348   0.219403
# PAY_3                       0.686775  ...   0.227202   0.225145   0.222327
# PAY_4                       0.819835  ...   0.245917   0.242902   0.239154
# PAY_5                       1.000000  ...   0.271915   0.269783   0.262509
# PAY_6                       0.816900  ...   0.266356   0.290894   0.285091
# BILL_AMT1                   0.206684  ...   0.860272   0.829779   0.802650
# BILL_AMT2                   0.226913  ...   0.892482   0.859778   0.831594
# BILL_AMT3                   0.243335  ...   0.923969   0.883910   0.853320
# BILL_AMT4                   0.271915  ...   1.000000   0.940134   0.900941
# BILL_AMT5                   0.269783  ...   0.940134   1.000000   0.946197
# BILL_AMT6                   0.262509  ...   0.900941   0.946197   1.000000
# PAY_AMT1                   -0.006089  ...   0.233012   0.217031   0.199965
# PAY_AMT2                   -0.003191  ...   0.207564   0.181246   0.172663
# PAY_AMT3                    0.009062  ...   0.300023   0.252305   0.233770
# PAY_AMT4                   -0.058299  ...   0.130191   0.293118   0.250237
# PAY_AMT5                   -0.033337  ...   0.160433   0.141574   0.307729
# PAY_AMT6                   -0.023027  ...   0.177637   0.164184   0.115494
# default payment next month  0.204149  ...  -0.010156  -0.006760  -0.005372
#
#                             PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# LIMIT_BAL                   0.195236  0.178408  0.210167  0.203242  0.217202
# SEX                        -0.000242 -0.001391 -0.008597 -0.002229 -0.001667
# EDUCATION                  -0.037456 -0.030038 -0.039943 -0.038218 -0.040358
# MARRIAGE                   -0.005979 -0.008093 -0.003541 -0.012659 -0.001205
# AGE                         0.026147  0.021785  0.029247  0.021379  0.022850
# PAY_0                      -0.079269 -0.070101 -0.070561 -0.064005 -0.058190
# PAY_2                      -0.080701 -0.058990 -0.055901 -0.046858 -0.037093
# PAY_3                       0.001295 -0.066793 -0.053311 -0.046067 -0.035863
# PAY_4                      -0.009362 -0.001944 -0.069235 -0.043461 -0.033590
# PAY_5                      -0.006089 -0.003191  0.009062 -0.058299 -0.033337
# PAY_6                      -0.001496 -0.005223  0.005834  0.019018 -0.046434
# BILL_AMT1                   0.140277  0.099355  0.156887  0.158303  0.167026
# BILL_AMT2                   0.280365  0.100851  0.150718  0.147398  0.157957
# BILL_AMT3                   0.244335  0.316936  0.130011  0.143405  0.179712
# BILL_AMT4                   0.233012  0.207564  0.300023  0.130191  0.160433
# BILL_AMT5                   0.217031  0.181246  0.252305  0.293118  0.141574
# BILL_AMT6                   0.199965  0.172663  0.233770  0.250237  0.307729
# PAY_AMT1                    1.000000  0.285576  0.252191  0.199558  0.148459
# PAY_AMT2                    0.285576  1.000000  0.244770  0.180107  0.180908
# PAY_AMT3                    0.252191  0.244770  1.000000  0.216325  0.159214
# PAY_AMT4                    0.199558  0.180107  0.216325  1.000000  0.151830
# PAY_AMT5                    0.148459  0.180908  0.159214  0.151830  1.000000
# PAY_AMT6                    0.185735  0.157634  0.162740  0.157834  0.154896
# default payment next month -0.072929 -0.058579 -0.056250 -0.056827 -0.055124
#
#                             PAY_AMT6  default payment next month
# LIMIT_BAL                   0.219595                   -0.153520
# SEX                        -0.002766                   -0.039961
# EDUCATION                  -0.037200                    0.028006
# MARRIAGE                   -0.006641                   -0.024339
# AGE                         0.019478                    0.013890
# PAY_0                      -0.058673                    0.324794
# PAY_2                      -0.036500                    0.263551
# PAY_3                      -0.035861                    0.235253
# PAY_4                      -0.026565                    0.216614
# PAY_5                      -0.023027                    0.204149
# PAY_6                      -0.025299                    0.186866
# BILL_AMT1                   0.179341                   -0.019644
# BILL_AMT2                   0.174256                   -0.014193
# BILL_AMT3                   0.182326                   -0.014076
# BILL_AMT4                   0.177637                   -0.010156
# BILL_AMT5                   0.164184                   -0.006760
# BILL_AMT6                   0.115494                   -0.005372
# PAY_AMT1                    0.185735                   -0.072929
# PAY_AMT2                    0.157634                   -0.058579
# PAY_AMT3                    0.162740                   -0.056250
# PAY_AMT4                    0.157834                   -0.056827
# PAY_AMT5                    0.154896                   -0.055124
# PAY_AMT6                    1.000000                   -0.053183
# default payment next month -0.053183                    1.000000
#
# [24 rows x 24 columns]

# %% [markdown]
# ##### covariance - measure how changes in one variable are associated with changes in a second variable

# %%
covMat = credit.cov()
print(covMat)
# Out:
#                                LIMIT_BAL          SEX     EDUCATION  \
# LIMIT_BAL                   1.683446e+10  1571.050630 -22474.028945
# SEX                         1.571051e+03     0.239247      0.005502
# EDUCATION                  -2.247403e+04     0.005502      0.624651
# MARRIAGE                   -7.323670e+03    -0.008014     -0.059184
# AGE                         1.730767e+05    -0.409726      1.275380
# PAY_0                      -3.954593e+04    -0.031685      0.093584
# PAY_2                      -4.603765e+04    -0.041442      0.115025
# PAY_3                      -4.443225e+04    -0.038694      0.107861
# PAY_4                      -4.057181e+04    -0.034411      0.100528
# PAY_5                      -3.667056e+04    -0.030521      0.087340
# PAY_6                      -3.509308e+04    -0.024754      0.074816
# BILL_AMT1                   2.727020e+09 -1211.694332   1372.377644
# BILL_AMT2                   2.570130e+09 -1085.595467   1054.657595
# BILL_AMT3                   2.548533e+09  -833.207432    712.664124
# BILL_AMT4                   2.453926e+09  -688.489572    -22.948827
# BILL_AMT5                   2.331481e+09  -505.694333   -363.577664
# BILL_AMT6                   2.243837e+09  -487.430160   -428.274232
# PAY_AMT1                    4.195711e+08    -1.964266   -490.330155
# PAY_AMT2                    5.333504e+08   -15.675500   -547.005021
# PAY_AMT3                    4.801180e+08   -74.034812   -555.834305
# PAY_AMT4                    4.131202e+08   -17.080110   -473.206951
# PAY_AMT5                    4.305657e+08   -12.458809   -487.335947
# PAY_AMT6                    5.065153e+08   -24.051885   -522.673379
# default payment next month -8.267552e+03    -0.008113      0.009187
#
#                                MARRIAGE            AGE         PAY_0  \
# LIMIT_BAL                  -7323.669658  173076.722569 -39545.930009
# SEX                           -0.008014      -0.409726     -0.031685
# EDUCATION                     -0.059184       1.275380      0.093584
# MARRIAGE                       0.272452      -1.992764      0.011683
# AGE                           -1.992764      84.969755     -0.408639
# PAY_0                          0.011683      -0.408639      1.262930
# PAY_2                          0.015122      -0.553408      0.904330
# PAY_3                          0.020421      -0.585263      0.772384
# PAY_4                          0.020213      -0.535851      0.707972
# PAY_5                          0.021074      -0.562245      0.648743
# PAY_6                          0.020616      -0.517022      0.613292
# BILL_AMT1                   -902.154685   38172.933546  15480.304170
# BILL_AMT2                   -802.517866   35613.657962  15185.916919
# BILL_AMT3                   -901.679085   34334.251320  14011.556537
# BILL_AMT4                   -783.881599   30453.108180  12950.248389
# BILL_AMT5                   -805.840875   27654.067800  12341.668685
# BILL_AMT6                   -659.223347   26137.648547  11844.759724
# PAY_AMT1                     -51.691615    3992.041735  -1475.495089
# PAY_AMT2                     -97.327974    4626.861549  -1815.138407
# PAY_AMT3                     -32.546082    4746.824393  -1396.168258
# PAY_AMT4                    -103.518204    3087.324192  -1126.847945
# PAY_AMT5                      -9.607709    3218.052172   -999.107730
# PAY_AMT6                     -61.623271    3191.903901  -1172.193614
# default payment next month    -0.005273       0.053143      0.151499
#
#                                    PAY_2         PAY_3         PAY_4  \
# LIMIT_BAL                  -46037.648360 -44432.253315 -40571.811859
# SEX                            -0.041442     -0.038694     -0.034411
# EDUCATION                       0.115025      0.107861      0.100528
# MARRIAGE                        0.015122      0.020421      0.020213
# AGE                            -0.553408     -0.585263     -0.535851
# PAY_0                           0.904330      0.772384      0.707972
# PAY_2                           1.433254      1.098371      0.926680
# PAY_3                           1.098371      1.432492      1.087761
# PAY_4                           0.926680      1.087761      1.366885
# PAY_5                           0.844886      0.931455      1.086161
# PAY_6                           0.792320      0.870815      0.963263
# BILL_AMT1                   20706.614217  18373.210469  17460.198259
# BILL_AMT2                   20045.829482  20214.071495  18790.627741
# BILL_AMT3                   18609.510991  18882.491544  19862.999426
# BILL_AMT4                   17116.298983  17494.100555  18496.423186
# BILL_AMT5                   16110.952468  16382.947539  17265.551898
# BILL_AMT6                   15642.875812  15847.089648  16651.586314
# PAY_AMT1                    -1600.240756     25.668468   -181.295613
# PAY_AMT2                    -1627.192336  -1841.952825    -52.358166
# PAY_AMT3                    -1178.331282  -1123.428782  -1425.205189
# PAY_AMT4                     -878.843879   -863.762183   -796.035739
# PAY_AMT5                     -678.468530   -655.796002   -599.991629
# PAY_AMT6                     -776.835035   -763.026041   -552.137338
# default payment next month      0.130960      0.116867      0.105115
#
#                                    PAY_5  ...     BILL_AMT4     BILL_AMT5  \
# LIMIT_BAL                  -36670.562325  ...  2.453926e+09  2.331481e+09
# SEX                            -0.030521  ... -6.884896e+02 -5.056943e+02
# EDUCATION                       0.087340  ... -2.294883e+01 -3.635777e+02
# MARRIAGE                        0.021074  ... -7.838816e+02 -8.058409e+02
# AGE                            -0.562245  ...  3.045311e+04  2.765407e+04
# PAY_0                           0.648743  ...  1.295025e+04  1.234167e+04
# PAY_2                           0.844886  ...  1.711630e+04  1.611095e+04
# PAY_3                           0.931455  ...  1.749410e+04  1.638295e+04
# PAY_4                           1.086161  ...  1.849642e+04  1.726555e+04
# PAY_5                           1.284114  ...  1.982293e+04  1.858659e+04
# PAY_6                           1.064545  ...  1.970555e+04  2.033812e+04
# BILL_AMT1                   17246.377531  ...  4.075286e+09  3.714795e+09
# BILL_AMT2                   18301.285286  ...  4.086508e+09  3.720401e+09
# BILL_AMT3                   19122.663330  ...  4.122238e+09  3.726780e+09
# BILL_AMT4                   19822.925512  ...  4.138716e+09  3.677105e+09
# BILL_AMT5                   18586.590324  ...  3.677105e+09  3.696294e+09
# BILL_AMT6                   17715.690075  ...  3.451762e+09  3.425914e+09
# PAY_AMT1                     -114.281714  ...  2.482888e+08  2.185501e+08
# PAY_AMT2                      -83.324487  ...  3.076686e+08  2.538936e+08
# PAY_AMT3                      180.812142  ...  3.398374e+08  2.700805e+08
# PAY_AMT4                    -1034.961970  ...  1.312133e+08  2.791830e+08
# PAY_AMT5                     -577.161017  ...  1.576892e+08  1.315051e+08
# PAY_AMT6                     -463.892613  ...  2.031590e+08  1.774537e+08
# default payment next month      0.096020  ... -2.711999e+02 -1.705974e+02
#
#                                BILL_AMT6      PAY_AMT1      PAY_AMT2  \
# LIMIT_BAL                   2.243837e+09  4.195711e+08  5.333504e+08
# SEX                        -4.874302e+02 -1.964266e+00 -1.567550e+01
# EDUCATION                  -4.282742e+02 -4.903302e+02 -5.470050e+02
# MARRIAGE                   -6.592233e+02 -5.169161e+01 -9.732797e+01
# AGE                         2.613765e+04  3.992042e+03  4.626862e+03
# PAY_0                       1.184476e+04 -1.475495e+03 -1.815138e+03
# PAY_2                       1.564288e+04 -1.600241e+03 -1.627192e+03
# PAY_3                       1.584709e+04  2.566847e+01 -1.841953e+03
# PAY_4                       1.665159e+04 -1.812956e+02 -5.235817e+01
# PAY_5                       1.771569e+04 -1.142817e+02 -8.332449e+01
# PAY_6                       1.952488e+04 -2.850067e+01 -1.383995e+02
# BILL_AMT1                   3.519876e+09  1.710894e+08  1.685692e+08
# BILL_AMT2                   3.524868e+09  3.305146e+08  1.653859e+08
# BILL_AMT3                   3.524247e+09  2.806565e+08  5.064226e+08
# BILL_AMT4                   3.451762e+09  2.482888e+08  3.076686e+08
# BILL_AMT5                   3.425914e+09  2.185501e+08  2.538936e+08
# BILL_AMT6                   3.546692e+09  1.972478e+08  2.369244e+08
# PAY_AMT1                    1.972478e+08  2.743423e+08  1.089849e+08
# PAY_AMT2                    2.369244e+08  1.089849e+08  5.308817e+08
# PAY_AMT3                    2.451233e+08  7.354626e+07  9.929841e+07
# PAY_AMT4                    2.334670e+08  5.178189e+07  6.501168e+07
# PAY_AMT5                    2.799982e+08  3.756893e+07  6.368414e+07
# PAY_AMT6                    1.222761e+08  5.469033e+07  6.456816e+07
# default payment next month -1.327963e+02 -5.013746e+02 -5.602107e+02
#
#                                 PAY_AMT3      PAY_AMT4      PAY_AMT5  \
# LIMIT_BAL                   4.801180e+08  4.131202e+08  4.305657e+08
# SEX                        -7.403481e+01 -1.708011e+01 -1.245881e+01
# EDUCATION                  -5.558343e+02 -4.732070e+02 -4.873359e+02
# MARRIAGE                   -3.254608e+01 -1.035182e+02 -9.607709e+00
# AGE                         4.746824e+03  3.087324e+03  3.218052e+03
# PAY_0                      -1.396168e+03 -1.126848e+03 -9.991077e+02
# PAY_2                      -1.178331e+03 -8.788439e+02 -6.784685e+02
# PAY_3                      -1.123429e+03 -8.637622e+02 -6.557960e+02
# PAY_4                      -1.425205e+03 -7.960357e+02 -5.999916e+02
# PAY_5                       1.808121e+02 -1.034962e+03 -5.771610e+02
# PAY_6                       1.181210e+02  3.426237e+02 -8.158327e+02
# BILL_AMT1                   2.034048e+08  1.826164e+08  1.879091e+08
# BILL_AMT2                   1.888731e+08  1.643518e+08  1.717652e+08
# BILL_AMT3                   1.587478e+08  1.558003e+08  1.904126e+08
# BILL_AMT4                   3.398374e+08  1.312133e+08  1.576892e+08
# BILL_AMT5                   2.700805e+08  2.791830e+08  1.315051e+08
# BILL_AMT6                   2.451233e+08  2.334670e+08  2.799982e+08
# PAY_AMT1                    7.354626e+07  5.178189e+07  3.756893e+07
# PAY_AMT2                    9.929841e+07  6.501168e+07  6.368414e+07
# PAY_AMT3                    3.100051e+08  5.966970e+07  4.282921e+07
# PAY_AMT4                    5.966970e+07  2.454286e+08  3.634098e+07
# PAY_AMT5                    4.282921e+07  3.634098e+07  2.334266e+08
# PAY_AMT6                    5.093879e+07  4.395747e+07  4.207110e+07
# default payment next month -4.110763e+02 -3.695159e+02 -3.495625e+02
#
#                                 PAY_AMT6  default payment next month
# LIMIT_BAL                   5.065153e+08                -8267.551759
# SEX                        -2.405188e+01                   -0.008113
# EDUCATION                  -5.226734e+02                    0.009187
# MARRIAGE                   -6.162327e+01                   -0.005273
# AGE                         3.191904e+03                    0.053143
# PAY_0                      -1.172194e+03                    0.151499
# PAY_2                      -7.768350e+02                    0.130960
# PAY_3                      -7.630260e+02                    0.116867
# PAY_4                      -5.521373e+02                    0.105115
# PAY_5                      -4.638926e+02                    0.096020
# PAY_6                      -5.172163e+02                    0.089194
# BILL_AMT1                   2.347681e+08                 -600.394108
# BILL_AMT2                   2.204845e+08                 -419.289137
# BILL_AMT3                   2.247817e+08                 -405.153680
# BILL_AMT4                   2.031590e+08                 -271.199885
# BILL_AMT5                   1.774537e+08                 -170.597447
# BILL_AMT6                   1.222761e+08                 -132.796294
# PAY_AMT1                    5.469033e+07                 -501.374552
# PAY_AMT2                    6.456816e+07                 -560.210740
# PAY_AMT3                    5.093879e+07                 -411.076284
# PAY_AMT4                    4.395747e+07                 -369.515887
# PAY_AMT5                    4.207110e+07                 -349.562530
# PAY_AMT6                    3.160383e+08                 -392.426415
# default payment next month -3.924264e+02                    0.172276
#
# [24 rows x 24 columns]

# %%
credit.to_csv(r'C:\Users\User\Desktop\new_credit1.csv', index = False)

# %% [markdown]
# # ----------------------------------------------------------------------------

# %% [markdown]
# # CREDIT DATA - PREPARATION & EDA

# %% [markdown]
# # -------------------------------------------------------------------------------

# %% [markdown]
# ### Libraries

# %%
import numpy as np
import pandas as pd
from pandas_profiling import ProfileReport
from pandas import Series, DataFrame
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Reading Data Set using Pandas

# %%
credit1 = pd.read_csv('new_credit1.csv')

# %% [markdown]
# ### Analysis

# %%
credit1
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0          20000    2          2         1   24      2      2     -1     -1
# 1         120000    2          2         2   26     -1      2      0      0
# 2          90000    2          2         2   34      0      0      0      0
# 3          50000    2          2         1   37      0      0      0      0
# 4          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0         -2  ...       689         0         0         0         0
# 1          0  ...      1000      1000      1000         0      2000
# 2          0  ...      1500      1000      1000      1000      5000
# 3          0  ...      2019      1200      1100      1069      1000
# 4          0  ...     36681     10000      9000       689       679
# ...      ...  ...       ...       ...       ...       ...       ...
# 29995      0  ...     20000      5003      3047      5000      1000
# 29996      0  ...      3526      8998       129         0         0
# 29997      0  ...         0     22000      4200      2000      3100
# 29998      0  ...      3409      1178      1926     52964      1804
# 29999      0  ...      1800      1430      1000      1000      1000
#
#        default_payment_next_month  age_bins  age_by_decade        limit_bins  \
# 0                               1  (20, 29]             20    (9999, 199999]
# 1                               1  (20, 29]             20    (9999, 199999]
# 2                               0  (29, 39]             30    (9999, 199999]
# 3                               0  (29, 39]             30    (9999, 199999]
# 4                               0  (49, 59]             50    (9999, 199999]
# ...                           ...       ...            ...               ...
# 29995                           0  (29, 39]             30  (199999, 299999]
# 29996                           0  (39, 49]             40    (9999, 199999]
# 29997                           1  (29, 39]             30    (9999, 199999]
# 29998                           1  (39, 49]             40    (9999, 199999]
# 29999                           1  (39, 49]             40    (9999, 199999]
#
#        limit_bal_gp
# 0             10000
# 1             10000
# 2             10000
# 3             10000
# 4             10000
# ...             ...
# 29995        200000
# 29996         10000
# 29997         10000
# 29998         10000
# 29999         10000
#
# [30000 rows x 28 columns]

# %%
credit1.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0      20000    2          2         1   24      2      2     -1     -1
# 1     120000    2          2         2   26     -1      2      0      0
# 2      90000    2          2         2   34      0      0      0      0
# 3      50000    2          2         1   37      0      0      0      0
# 4      50000    1          2         1   57     -1      0     -1      0
#
#    PAY_5  ...  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 0     -2  ...       689         0         0         0         0
# 1      0  ...      1000      1000      1000         0      2000
# 2      0  ...      1500      1000      1000      1000      5000
# 3      0  ...      2019      1200      1100      1069      1000
# 4      0  ...     36681     10000      9000       689       679
#
#    default_payment_next_month  age_bins  age_by_decade      limit_bins  \
# 0                           1  (20, 29]             20  (9999, 199999]
# 1                           1  (20, 29]             20  (9999, 199999]
# 2                           0  (29, 39]             30  (9999, 199999]
# 3                           0  (29, 39]             30  (9999, 199999]
# 4                           0  (49, 59]             50  (9999, 199999]
#
#    limit_bal_gp
# 0         10000
# 1         10000
# 2         10000
# 3         10000
# 4         10000
#
# [5 rows x 28 columns]

# %%
credit1.tail()
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 29995     220000    1          3         1   39      0      0      0      0
# 29996     150000    1          3         2   43     -1     -1     -1     -1
# 29997      30000    1          2         2   37      4      3      2     -1
# 29998      80000    1          3         1   41      1     -1      0      0
# 29999      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# 29995      0  ...     20000      5003      3047      5000      1000
# 29996      0  ...      3526      8998       129         0         0
# 29997      0  ...         0     22000      4200      2000      3100
# 29998      0  ...      3409      1178      1926     52964      1804
# 29999      0  ...      1800      1430      1000      1000      1000
#
#        default_payment_next_month  age_bins  age_by_decade        limit_bins  \
# 29995                           0  (29, 39]             30  (199999, 299999]
# 29996                           0  (39, 49]             40    (9999, 199999]
# 29997                           1  (29, 39]             30    (9999, 199999]
# 29998                           1  (39, 49]             40    (9999, 199999]
# 29999                           1  (39, 49]             40    (9999, 199999]
#
#        limit_bal_gp
# 29995        200000
# 29996         10000
# 29997         10000
# 29998         10000
# 29999         10000
#
# [5 rows x 28 columns]

# %%
credit1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 28 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# BILL_AMT6                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default_payment_next_month    30000 non-null int64
# age_bins                      30000 non-null object
# age_by_decade                 30000 non-null int64
# limit_bins                    30000 non-null object
# limit_bal_gp                  30000 non-null int64
# dtypes: int64(26), object(2)
# memory usage: 6.4+ MB

# %%
credit1.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT6       PAY_AMT1      PAY_AMT2      PAY_AMT3  \
# count  ...   30000.000000   30000.000000  3.000000e+04   30000.00000
# mean   ...   38871.760400    5663.580500  5.921163e+03    5225.68150
# std    ...   59554.107537   16563.280354  2.304087e+04   17606.96147
# min    ... -339603.000000       0.000000  0.000000e+00       0.00000
# 25%    ...    1256.000000    1000.000000  8.330000e+02     390.00000
# 50%    ...   17071.000000    2100.000000  2.009000e+03    1800.00000
# 75%    ...   49198.250000    5006.000000  5.000000e+03    4505.00000
# max    ...  961664.000000  873552.000000  1.684259e+06  896040.00000
#
#             PAY_AMT4       PAY_AMT5       PAY_AMT6  \
# count   30000.000000   30000.000000   30000.000000
# mean     4826.076867    4799.387633    5215.502567
# std     15666.159744   15278.305679   17777.465775
# min         0.000000       0.000000       0.000000
# 25%       296.000000     252.500000     117.750000
# 50%      1500.000000    1500.000000    1500.000000
# 75%      4013.250000    4031.500000    4000.000000
# max    621000.000000  426529.000000  528666.000000
#
#        default_payment_next_month  age_by_decade    limit_bal_gp
# count                30000.000000   30000.000000    30000.000000
# mean                     0.221200      30.856667   108120.000000
# std                      0.415062       9.738717   141081.167169
# min                      0.000000      20.000000    10000.000000
# 25%                      0.000000      20.000000    10000.000000
# 50%                      0.000000      30.000000    10000.000000
# 75%                      0.000000      40.000000   200000.000000
# max                      1.000000      70.000000  1000000.000000
#
# [8 rows x 26 columns]

# %%
credit.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default payment next month    0
# age_bins                      0
# age_by_decade                 0
# limit_bins                    0
# limit_bal_gp                  0
# dtype: int64

# %%
credit1.columns
# Out:
# Index(['LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_0', 'PAY_2',
#        'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2',
#        'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1',
#        'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6',
#        'default_payment_next_month', 'age_bins', 'age_by_decade', 'limit_bins',
#        'limit_bal_gp'],
#       dtype='object')

# %% [markdown]
# ##### plots

# %%
plt.hist(credit1['LIMIT_BAL'], bins=5)
# Out:
# (array([2.0378e+04, 7.8180e+03, 1.7250e+03, 7.8000e+01, 1.0000e+00]),
#  array([  10000.,  208000.,  406000.,  604000.,  802000., 1000000.]),
#  <a list of 5 Patch objects>)

# %%
plt.hist(credit['limit_bal_gp'])
# Out:
# (array([1.885e+04, 8.330e+02, 6.033e+03, 6.400e+01, 0.000e+00, 3.042e+03,
#         1.147e+03, 2.800e+01, 1.000e+00, 2.000e+00]),
#  array([0. , 0.8, 1.6, 2.4, 3.2, 4. , 4.8, 5.6, 6.4, 7.2, 8. ]),
#  <a list of 10 Patch objects>)

# %%
A = credit1['BILL_AMT1']
plt.boxplot(A,0,'gD')
plt.show()

# %%
corrMat = credit1.corr()
print(corrMat)
# Out:
#                             LIMIT_BAL       SEX  EDUCATION  MARRIAGE  \
# LIMIT_BAL                    1.000000  0.024755  -0.219161 -0.108139
# SEX                          0.024755  1.000000   0.014232 -0.031389
# EDUCATION                   -0.219161  0.014232   1.000000 -0.143464
# MARRIAGE                    -0.108139 -0.031389  -0.143464  1.000000
# AGE                          0.144713 -0.090874   0.175061 -0.414170
# PAY_0                       -0.271214 -0.057643   0.105364  0.019917
# PAY_2                       -0.296382 -0.070771   0.121566  0.024199
# PAY_3                       -0.286123 -0.066096   0.114025  0.032688
# PAY_4                       -0.267460 -0.060173   0.108793  0.033122
# PAY_5                       -0.249411 -0.055064   0.097520  0.035629
# PAY_6                       -0.235195 -0.044008   0.082316  0.034345
# BILL_AMT1                    0.285430 -0.033642   0.023581 -0.023472
# BILL_AMT2                    0.278314 -0.031183   0.018749 -0.021602
# BILL_AMT3                    0.283236 -0.024563   0.013002 -0.024909
# BILL_AMT4                    0.293988 -0.021880  -0.000451 -0.023344
# BILL_AMT5                    0.295562 -0.017005  -0.007567 -0.025393
# BILL_AMT6                    0.290389 -0.016733  -0.009099 -0.021207
# PAY_AMT1                     0.195236 -0.000242  -0.037456 -0.005979
# PAY_AMT2                     0.178408 -0.001391  -0.030038 -0.008093
# PAY_AMT3                     0.210167 -0.008597  -0.039943 -0.003541
# PAY_AMT4                     0.203242 -0.002229  -0.038218 -0.012659
# PAY_AMT5                     0.217202 -0.001667  -0.040358 -0.001205
# PAY_AMT6                     0.219595 -0.002766  -0.037200 -0.006641
# default_payment_next_month  -0.153520 -0.039961   0.028006 -0.024339
# age_by_decade                0.133872 -0.084366   0.173686 -0.400690
# limit_bal_gp                 0.937519  0.001696  -0.197724 -0.096773
#
#                                  AGE     PAY_0     PAY_2     PAY_3     PAY_4  \
# LIMIT_BAL                   0.144713 -0.271214 -0.296382 -0.286123 -0.267460
# SEX                        -0.090874 -0.057643 -0.070771 -0.066096 -0.060173
# EDUCATION                   0.175061  0.105364  0.121566  0.114025  0.108793
# MARRIAGE                   -0.414170  0.019917  0.024199  0.032688  0.033122
# AGE                         1.000000 -0.039447 -0.050148 -0.053048 -0.049722
# PAY_0                      -0.039447  1.000000  0.672164  0.574245  0.538841
# PAY_2                      -0.050148  0.672164  1.000000  0.766552  0.662067
# PAY_3                      -0.053048  0.574245  0.766552  1.000000  0.777359
# PAY_4                      -0.049722  0.538841  0.662067  0.777359  1.000000
# PAY_5                      -0.053826  0.509426  0.622780  0.686775  0.819835
# PAY_6                      -0.048773  0.474553  0.575501  0.632684  0.716449
# BILL_AMT1                   0.056239  0.187068  0.234887  0.208473  0.202812
# BILL_AMT2                   0.054283  0.189859  0.235257  0.237295  0.225816
# BILL_AMT3                   0.053710  0.179785  0.224146  0.227494  0.244983
# BILL_AMT4                   0.051353  0.179125  0.222237  0.227202  0.245917
# BILL_AMT5                   0.049345  0.180635  0.221348  0.225145  0.242902
# BILL_AMT6                   0.047613  0.176980  0.219403  0.222327  0.239154
# PAY_AMT1                    0.026147 -0.079269 -0.080701  0.001295 -0.009362
# PAY_AMT2                    0.021785 -0.070101 -0.058990 -0.066793 -0.001944
# PAY_AMT3                    0.029247 -0.070561 -0.055901 -0.053311 -0.069235
# PAY_AMT4                    0.021379 -0.064005 -0.046858 -0.046067 -0.043461
# PAY_AMT5                    0.022850 -0.058190 -0.037093 -0.035863 -0.033590
# PAY_AMT6                    0.019478 -0.058673 -0.036500 -0.035861 -0.026565
# default_payment_next_month  0.013890  0.324794  0.263551  0.235253  0.216614
# age_by_decade               0.957266 -0.036857 -0.046066 -0.047784 -0.045347
# limit_bal_gp                0.136534 -0.241451 -0.259107 -0.247886 -0.230371
#
#                                PAY_5  ...  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# LIMIT_BAL                  -0.249411  ...   0.290389  0.195236  0.178408
# SEX                        -0.055064  ...  -0.016733 -0.000242 -0.001391
# EDUCATION                   0.097520  ...  -0.009099 -0.037456 -0.030038
# MARRIAGE                    0.035629  ...  -0.021207 -0.005979 -0.008093
# AGE                        -0.053826  ...   0.047613  0.026147  0.021785
# PAY_0                       0.509426  ...   0.176980 -0.079269 -0.070101
# PAY_2                       0.622780  ...   0.219403 -0.080701 -0.058990
# PAY_3                       0.686775  ...   0.222327  0.001295 -0.066793
# PAY_4                       0.819835  ...   0.239154 -0.009362 -0.001944
# PAY_5                       1.000000  ...   0.262509 -0.006089 -0.003191
# PAY_6                       0.816900  ...   0.285091 -0.001496 -0.005223
# BILL_AMT1                   0.206684  ...   0.802650  0.140277  0.099355
# BILL_AMT2                   0.226913  ...   0.831594  0.280365  0.100851
# BILL_AMT3                   0.243335  ...   0.853320  0.244335  0.316936
# BILL_AMT4                   0.271915  ...   0.900941  0.233012  0.207564
# BILL_AMT5                   0.269783  ...   0.946197  0.217031  0.181246
# BILL_AMT6                   0.262509  ...   1.000000  0.199965  0.172663
# PAY_AMT1                   -0.006089  ...   0.199965  1.000000  0.285576
# PAY_AMT2                   -0.003191  ...   0.172663  0.285576  1.000000
# PAY_AMT3                    0.009062  ...   0.233770  0.252191  0.244770
# PAY_AMT4                   -0.058299  ...   0.250237  0.199558  0.180107
# PAY_AMT5                   -0.033337  ...   0.307729  0.148459  0.180908
# PAY_AMT6                   -0.023027  ...   0.115494  0.185735  0.157634
# default_payment_next_month  0.204149  ...  -0.005372 -0.072929 -0.058579
# age_by_decade              -0.049775  ...   0.042291  0.023195  0.020793
# limit_bal_gp               -0.214165  ...   0.244162  0.181463  0.169958
#
#                             PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  \
# LIMIT_BAL                   0.210167  0.203242  0.217202  0.219595
# SEX                        -0.008597 -0.002229 -0.001667 -0.002766
# EDUCATION                  -0.039943 -0.038218 -0.040358 -0.037200
# MARRIAGE                   -0.003541 -0.012659 -0.001205 -0.006641
# AGE                         0.029247  0.021379  0.022850  0.019478
# PAY_0                      -0.070561 -0.064005 -0.058190 -0.058673
# PAY_2                      -0.055901 -0.046858 -0.037093 -0.036500
# PAY_3                      -0.053311 -0.046067 -0.035863 -0.035861
# PAY_4                      -0.069235 -0.043461 -0.033590 -0.026565
# PAY_5                       0.009062 -0.058299 -0.033337 -0.023027
# PAY_6                       0.005834  0.019018 -0.046434 -0.025299
# BILL_AMT1                   0.156887  0.158303  0.167026  0.179341
# BILL_AMT2                   0.150718  0.147398  0.157957  0.174256
# BILL_AMT3                   0.130011  0.143405  0.179712  0.182326
# BILL_AMT4                   0.300023  0.130191  0.160433  0.177637
# BILL_AMT5                   0.252305  0.293118  0.141574  0.164184
# BILL_AMT6                   0.233770  0.250237  0.307729  0.115494
# PAY_AMT1                    0.252191  0.199558  0.148459  0.185735
# PAY_AMT2                    0.244770  0.180107  0.180908  0.157634
# PAY_AMT3                    1.000000  0.216325  0.159214  0.162740
# PAY_AMT4                    0.216325  1.000000  0.151830  0.157834
# PAY_AMT5                    0.159214  0.151830  1.000000  0.154896
# PAY_AMT6                    0.162740  0.157834  0.154896  1.000000
# default_payment_next_month -0.056250 -0.056827 -0.055124 -0.053183
# age_by_decade               0.029233  0.021131  0.019370  0.020354
# limit_bal_gp                0.198911  0.188239  0.202797  0.209493
#
#                             default_payment_next_month  age_by_decade  \
# LIMIT_BAL                                    -0.153520       0.133872
# SEX                                          -0.039961      -0.084366
# EDUCATION                                     0.028006       0.173686
# MARRIAGE                                     -0.024339      -0.400690
# AGE                                           0.013890       0.957266
# PAY_0                                         0.324794      -0.036857
# PAY_2                                         0.263551      -0.046066
# PAY_3                                         0.235253      -0.047784
# PAY_4                                         0.216614      -0.045347
# PAY_5                                         0.204149      -0.049775
# PAY_6                                         0.186866      -0.044524
# BILL_AMT1                                    -0.019644       0.052579
# BILL_AMT2                                    -0.014193       0.050514
# BILL_AMT3                                    -0.014076       0.049748
# BILL_AMT4                                    -0.010156       0.047599
# BILL_AMT5                                    -0.006760       0.044749
# BILL_AMT6                                    -0.005372       0.042291
# PAY_AMT1                                     -0.072929       0.023195
# PAY_AMT2                                     -0.058579       0.020793
# PAY_AMT3                                     -0.056250       0.029233
# PAY_AMT4                                     -0.056827       0.021131
# PAY_AMT5                                     -0.055124       0.019370
# PAY_AMT6                                     -0.053183       0.020354
# default_payment_next_month                    1.000000       0.014722
# age_by_decade                                 0.014722       1.000000
# limit_bal_gp                                 -0.127625       0.129801
#
#                             limit_bal_gp
# LIMIT_BAL                       0.937519
# SEX                             0.001696
# EDUCATION                      -0.197724
# MARRIAGE                       -0.096773
# AGE                             0.136534
# PAY_0                          -0.241451
# PAY_2                          -0.259107
# PAY_3                          -0.247886
# PAY_4                          -0.230371
# PAY_5                          -0.214165
# PAY_6                          -0.205667
# BILL_AMT1                       0.238181
# BILL_AMT2                       0.231844
# BILL_AMT3                       0.238413
# BILL_AMT4                       0.249981
# BILL_AMT5                       0.250463
# BILL_AMT6                       0.244162
# PAY_AMT1                        0.181463
# PAY_AMT2                        0.169958
# PAY_AMT3                        0.198911
# PAY_AMT4                        0.188239
# PAY_AMT5                        0.202797
# PAY_AMT6                        0.209493
# default_payment_next_month     -0.127625
# age_by_decade                   0.129801
# limit_bal_gp                    1.000000
#
# [26 rows x 26 columns]

# %%
covMat = credit1.cov()
print(covMat)
# Out:
#                                LIMIT_BAL          SEX     EDUCATION  \
# LIMIT_BAL                   1.683446e+10  1571.050630 -22474.028945
# SEX                         1.571051e+03     0.239247      0.005502
# EDUCATION                  -2.247403e+04     0.005502      0.624651
# MARRIAGE                   -7.323670e+03    -0.008014     -0.059184
# AGE                         1.730767e+05    -0.409726      1.275380
# PAY_0                      -3.954593e+04    -0.031685      0.093584
# PAY_2                      -4.603765e+04    -0.041442      0.115025
# PAY_3                      -4.443225e+04    -0.038694      0.107861
# PAY_4                      -4.057181e+04    -0.034411      0.100528
# PAY_5                      -3.667056e+04    -0.030521      0.087340
# PAY_6                      -3.509308e+04    -0.024754      0.074816
# BILL_AMT1                   2.727020e+09 -1211.694332   1372.377644
# BILL_AMT2                   2.570130e+09 -1085.595467   1054.657595
# BILL_AMT3                   2.548533e+09  -833.207432    712.664124
# BILL_AMT4                   2.453926e+09  -688.489572    -22.948827
# BILL_AMT5                   2.331481e+09  -505.694333   -363.577664
# BILL_AMT6                   2.243837e+09  -487.430160   -428.274232
# PAY_AMT1                    4.195711e+08    -1.964266   -490.330155
# PAY_AMT2                    5.333504e+08   -15.675500   -547.005021
# PAY_AMT3                    4.801180e+08   -74.034812   -555.834305
# PAY_AMT4                    4.131202e+08   -17.080110   -473.206951
# PAY_AMT5                    4.305657e+08   -12.458809   -487.335947
# PAY_AMT6                    5.065153e+08   -24.051885   -522.673379
# default_payment_next_month -8.267552e+03    -0.008113      0.009187
# age_by_decade               1.691573e+05    -0.401878      1.336860
# limit_bal_gp                1.716123e+10   117.022567 -22046.844228
#
#                                MARRIAGE            AGE         PAY_0  \
# LIMIT_BAL                  -7323.669658  173076.722569 -39545.930009
# SEX                           -0.008014      -0.409726     -0.031685
# EDUCATION                     -0.059184       1.275380      0.093584
# MARRIAGE                       0.272452      -1.992764      0.011683
# AGE                           -1.992764      84.969755     -0.408639
# PAY_0                          0.011683      -0.408639      1.262930
# PAY_2                          0.015122      -0.553408      0.904330
# PAY_3                          0.020421      -0.585263      0.772384
# PAY_4                          0.020213      -0.535851      0.707972
# PAY_5                          0.021074      -0.562245      0.648743
# PAY_6                          0.020616      -0.517022      0.613292
# BILL_AMT1                   -902.154685   38172.933546  15480.304170
# BILL_AMT2                   -802.517866   35613.657962  15185.916919
# BILL_AMT3                   -901.679085   34334.251320  14011.556537
# BILL_AMT4                   -783.881599   30453.108180  12950.248389
# BILL_AMT5                   -805.840875   27654.067800  12341.668685
# BILL_AMT6                   -659.223347   26137.648547  11844.759724
# PAY_AMT1                     -51.691615    3992.041735  -1475.495089
# PAY_AMT2                     -97.327974    4626.861549  -1815.138407
# PAY_AMT3                     -32.546082    4746.824393  -1396.168258
# PAY_AMT4                    -103.518204    3087.324192  -1126.847945
# PAY_AMT5                      -9.607709    3218.052172   -999.107730
# PAY_AMT6                     -61.623271    3191.903901  -1172.193614
# default_payment_next_month    -0.005273       0.053143      0.151499
# age_by_decade                 -2.036834      85.934286     -0.403374
# limit_bal_gp               -7126.394880  177558.658622 -38281.338711
#
#                                    PAY_2         PAY_3         PAY_4  \
# LIMIT_BAL                  -46037.648360 -44432.253315 -40571.811859
# SEX                            -0.041442     -0.038694     -0.034411
# EDUCATION                       0.115025      0.107861      0.100528
# MARRIAGE                        0.015122      0.020421      0.020213
# AGE                            -0.553408     -0.585263     -0.535851
# PAY_0                           0.904330      0.772384      0.707972
# PAY_2                           1.433254      1.098371      0.926680
# PAY_3                           1.098371      1.432492      1.087761
# PAY_4                           0.926680      1.087761      1.366885
# PAY_5                           0.844886      0.931455      1.086161
# PAY_6                           0.792320      0.870815      0.963263
# BILL_AMT1                   20706.614217  18373.210469  17460.198259
# BILL_AMT2                   20045.829482  20214.071495  18790.627741
# BILL_AMT3                   18609.510991  18882.491544  19862.999426
# BILL_AMT4                   17116.298983  17494.100555  18496.423186
# BILL_AMT5                   16110.952468  16382.947539  17265.551898
# BILL_AMT6                   15642.875812  15847.089648  16651.586314
# PAY_AMT1                    -1600.240756     25.668468   -181.295613
# PAY_AMT2                    -1627.192336  -1841.952825    -52.358166
# PAY_AMT3                    -1178.331282  -1123.428782  -1425.205189
# PAY_AMT4                     -878.843879   -863.762183   -796.035739
# PAY_AMT5                     -678.468530   -655.796002   -599.991629
# PAY_AMT6                     -776.835035   -763.026041   -552.137338
# default_payment_next_month      0.130960      0.116867      0.105115
# age_by_decade                  -0.537091     -0.556974     -0.516313
# limit_bal_gp               -43763.273442 -41856.851228 -37998.119937
#
#                                    PAY_5  ...     BILL_AMT6      PAY_AMT1  \
# LIMIT_BAL                  -36670.562325  ...  2.243837e+09  4.195711e+08
# SEX                            -0.030521  ... -4.874302e+02 -1.964266e+00
# EDUCATION                       0.087340  ... -4.282742e+02 -4.903302e+02
# MARRIAGE                        0.021074  ... -6.592233e+02 -5.169161e+01
# AGE                            -0.562245  ...  2.613765e+04  3.992042e+03
# PAY_0                           0.648743  ...  1.184476e+04 -1.475495e+03
# PAY_2                           0.844886  ...  1.564288e+04 -1.600241e+03
# PAY_3                           0.931455  ...  1.584709e+04  2.566847e+01
# PAY_4                           1.086161  ...  1.665159e+04 -1.812956e+02
# PAY_5                           1.284114  ...  1.771569e+04 -1.142817e+02
# PAY_6                           1.064545  ...  1.952488e+04 -2.850067e+01
# BILL_AMT1                   17246.377531  ...  3.519876e+09  1.710894e+08
# BILL_AMT2                   18301.285286  ...  3.524868e+09  3.305146e+08
# BILL_AMT3                   19122.663330  ...  3.524247e+09  2.806565e+08
# BILL_AMT4                   19822.925512  ...  3.451762e+09  2.482888e+08
# BILL_AMT5                   18586.590324  ...  3.425914e+09  2.185501e+08
# BILL_AMT6                   17715.690075  ...  3.546692e+09  1.972478e+08
# PAY_AMT1                     -114.281714  ...  1.972478e+08  2.743423e+08
# PAY_AMT2                      -83.324487  ...  2.369244e+08  1.089849e+08
# PAY_AMT3                      180.812142  ...  2.451233e+08  7.354626e+07
# PAY_AMT4                    -1034.961970  ...  2.334670e+08  5.178189e+07
# PAY_AMT5                     -577.161017  ...  2.799982e+08  3.756893e+07
# PAY_AMT6                     -463.892613  ...  1.222761e+08  5.469033e+07
# default_payment_next_month      0.096020  ... -1.327963e+02 -5.013746e+02
# age_by_decade                  -0.549307  ...  2.452779e+04  3.741476e+03
# limit_bal_gp               -34238.930631  ...  2.051443e+09  4.240363e+08
#
#                                 PAY_AMT2      PAY_AMT3      PAY_AMT4  \
# LIMIT_BAL                   5.333504e+08  4.801180e+08  4.131202e+08
# SEX                        -1.567550e+01 -7.403481e+01 -1.708011e+01
# EDUCATION                  -5.470050e+02 -5.558343e+02 -4.732070e+02
# MARRIAGE                   -9.732797e+01 -3.254608e+01 -1.035182e+02
# AGE                         4.626862e+03  4.746824e+03  3.087324e+03
# PAY_0                      -1.815138e+03 -1.396168e+03 -1.126848e+03
# PAY_2                      -1.627192e+03 -1.178331e+03 -8.788439e+02
# PAY_3                      -1.841953e+03 -1.123429e+03 -8.637622e+02
# PAY_4                      -5.235817e+01 -1.425205e+03 -7.960357e+02
# PAY_5                      -8.332449e+01  1.808121e+02 -1.034962e+03
# PAY_6                      -1.383995e+02  1.181210e+02  3.426237e+02
# BILL_AMT1                   1.685692e+08  2.034048e+08  1.826164e+08
# BILL_AMT2                   1.653859e+08  1.888731e+08  1.643518e+08
# BILL_AMT3                   5.064226e+08  1.587478e+08  1.558003e+08
# BILL_AMT4                   3.076686e+08  3.398374e+08  1.312133e+08
# BILL_AMT5                   2.538936e+08  2.700805e+08  2.791830e+08
# BILL_AMT6                   2.369244e+08  2.451233e+08  2.334670e+08
# PAY_AMT1                    1.089849e+08  7.354626e+07  5.178189e+07
# PAY_AMT2                    5.308817e+08  9.929841e+07  6.501168e+07
# PAY_AMT3                    9.929841e+07  3.100051e+08  5.966970e+07
# PAY_AMT4                    6.501168e+07  5.966970e+07  2.454286e+08
# PAY_AMT5                    6.368414e+07  4.282921e+07  3.634098e+07
# PAY_AMT6                    6.456816e+07  5.093879e+07  4.395747e+07
# default_payment_next_month -5.602107e+02 -4.110763e+02 -3.695159e+02
# age_by_decade               4.665718e+03  5.012501e+03  3.223993e+03
# limit_bal_gp                5.524723e+08  4.940971e+08  4.160449e+08
#
#                                 PAY_AMT5      PAY_AMT6  \
# LIMIT_BAL                   4.305657e+08  5.065153e+08
# SEX                        -1.245881e+01 -2.405188e+01
# EDUCATION                  -4.873359e+02 -5.226734e+02
# MARRIAGE                   -9.607709e+00 -6.162327e+01
# AGE                         3.218052e+03  3.191904e+03
# PAY_0                      -9.991077e+02 -1.172194e+03
# PAY_2                      -6.784685e+02 -7.768350e+02
# PAY_3                      -6.557960e+02 -7.630260e+02
# PAY_4                      -5.999916e+02 -5.521373e+02
# PAY_5                      -5.771610e+02 -4.638926e+02
# PAY_6                      -8.158327e+02 -5.172163e+02
# BILL_AMT1                   1.879091e+08  2.347681e+08
# BILL_AMT2                   1.717652e+08  2.204845e+08
# BILL_AMT3                   1.904126e+08  2.247817e+08
# BILL_AMT4                   1.576892e+08  2.031590e+08
# BILL_AMT5                   1.315051e+08  1.774537e+08
# BILL_AMT6                   2.799982e+08  1.222761e+08
# PAY_AMT1                    3.756893e+07  5.469033e+07
# PAY_AMT2                    6.368414e+07  6.456816e+07
# PAY_AMT3                    4.282921e+07  5.093879e+07
# PAY_AMT4                    3.634098e+07  4.395747e+07
# PAY_AMT5                    2.334266e+08  4.207110e+07
# PAY_AMT6                    4.207110e+07  3.160383e+08
# default_payment_next_month -3.495625e+02 -3.924264e+02
# age_by_decade               2.882103e+03  3.523819e+03
# limit_bal_gp                4.371253e+08  5.254223e+08
#
#                             default_payment_next_month  age_by_decade  \
# LIMIT_BAL                                 -8267.551759  169157.295492
# SEX                                          -0.008113      -0.401878
# EDUCATION                                     0.009187       1.336860
# MARRIAGE                                     -0.005273      -2.036834
# AGE                                           0.053143      85.934286
# PAY_0                                         0.151499      -0.403374
# PAY_2                                         0.130960      -0.537091
# PAY_3                                         0.116867      -0.556974
# PAY_4                                         0.105115      -0.516313
# PAY_5                                         0.096020      -0.549307
# PAY_6                                         0.089194      -0.498641
# BILL_AMT1                                  -600.394108   37705.163034
# BILL_AMT2                                  -419.289137   35013.233715
# BILL_AMT3                                  -405.153680   33598.524005
# BILL_AMT4                                  -271.199885   29821.705442
# BILL_AMT5                                  -170.597447   26495.455020
# BILL_AMT6                                  -132.796294   24527.787850
# PAY_AMT1                                   -501.374552    3741.476421
# PAY_AMT2                                   -560.210740    4665.718126
# PAY_AMT3                                   -411.076284    5012.501265
# PAY_AMT4                                   -369.515887    3223.992617
# PAY_AMT5                                   -349.562530    2882.102664
# PAY_AMT6                                   -392.426415    3523.818929
# default_payment_next_month                    0.172276       0.059507
# age_by_decade                                 0.059507      94.842617
# limit_bal_gp                              -7473.393113  178339.811327
#
#                             limit_bal_gp
# LIMIT_BAL                   1.716123e+10
# SEX                         1.170226e+02
# EDUCATION                  -2.204684e+04
# MARRIAGE                   -7.126395e+03
# AGE                         1.775587e+05
# PAY_0                      -3.828134e+04
# PAY_2                      -4.376327e+04
# PAY_3                      -4.185685e+04
# PAY_4                      -3.799812e+04
# PAY_5                      -3.423893e+04
# PAY_6                      -3.336771e+04
# BILL_AMT1                   2.474379e+09
# BILL_AMT2                   2.328012e+09
# BILL_AMT3                   2.332602e+09
# BILL_AMT4                   2.268869e+09
# BILL_AMT5                   2.148303e+09
# BILL_AMT6                   2.051443e+09
# PAY_AMT1                    4.240363e+08
# PAY_AMT2                    5.524723e+08
# PAY_AMT3                    4.940971e+08
# PAY_AMT4                    4.160449e+08
# PAY_AMT5                    4.371253e+08
# PAY_AMT6                    5.254223e+08
# default_payment_next_month -7.473393e+03
# age_by_decade               1.783398e+05
# limit_bal_gp                1.990390e+10
#
# [26 rows x 26 columns]

# %% [markdown]
# ##### Attributes in split

# %%
credit1.groupby('SEX')['SEX'].count()
# Out:
# SEX
# 1    11888
# 2    18112
# Name: SEX, dtype: int64

# %%
sns.factorplot('SEX',data=credit1,kind='count',aspect=1.5)
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#Default next month and gender
credit1.groupby(['SEX','default_payment_next_month'])['default_payment_next_month'].count()
# Out:
# SEX  default_payment_next_month
# 1    0                              9015
#      1                              2873
# 2    0                             14349
#      1                              3763
# Name: default_payment_next_month, dtype: int64

# %%
#Default next month and gender chart
defaultgender = sns.factorplot('SEX', data=credit1, hue='default_payment_next_month', kind='count', aspect=1.75)
defaultgender.set_xlabels('SEX')

# %%
sns.factorplot('SEX',data=credit1, kind='count', hue='age_by_decade',col='default_payment_next_month',aspect=1.25, height=5)

# %%
credit1.groupby('MARRIAGE')['MARRIAGE'].count()
# Out:
# MARRIAGE
# 0       54
# 1    13659
# 2    15964
# 3      323
# Name: MARRIAGE, dtype: int64

# %%
sns.factorplot('MARRIAGE',data=credit1,kind='count',aspect=1.5)

# %%
#Default next month and marriage
credit1.groupby(['MARRIAGE','default_payment_next_month'])['default_payment_next_month'].count()
# Out:
# MARRIAGE  default_payment_next_month
# 0         0                                49
#           1                                 5
# 1         0                             10453
#           1                              3206
# 2         0                             12623
#           1                              3341
# 3         0                               239
#           1                                84
# Name: default_payment_next_month, dtype: int64

# %%
#Default next month and marriage chart
defaultgender = sns.factorplot('MARRIAGE', data=credit1, hue='default_payment_next_month', kind='count', aspect=1.75)
defaultgender.set_xlabels('MARRIAGE')

# %%
credit1.groupby('age_by_decade')['age_by_decade'].count()
# Out:
# age_by_decade
# 20     9618
# 30    11238
# 40     6464
# 50     2341
# 60      314
# 70       25
# Name: age_by_decade, dtype: int64

# %%
sns.factorplot('age_by_decade',data=credit1,kind='count',aspect=1.5)

# %%
#Default next month and age by decade
credit1.groupby(['age_by_decade','default_payment_next_month'])['default_payment_next_month'].count()
# Out:
# age_by_decade  default_payment_next_month
# 20             0                             7421
#                1                             2197
# 30             0                             8962
#                1                             2276
# 40             0                             4979
#                1                             1485
# 50             0                             1759
#                1                              582
# 60             0                              225
#                1                               89
# 70             0                               18
#                1                                7
# Name: default_payment_next_month, dtype: int64

# %%
#Default next month and age chart
defaultgender = sns.factorplot('age_by_decade', data=credit1, hue='default_payment_next_month', kind='count', aspect=1.75)
defaultgender.set_xlabels('age_by_decade')

# %%
credit1.groupby('EDUCATION')['EDUCATION'].count()
# Out:
# EDUCATION
# 0       14
# 1    10585
# 2    14030
# 3     4917
# 4      123
# 5      280
# 6       51
# Name: EDUCATION, dtype: int64

# %%
sns.factorplot('EDUCATION',data=credit1,kind='count',aspect=1.5)

# %%
#Default next month and education
credit1.groupby(['EDUCATION','default_payment_next_month'])['default_payment_next_month'].count()
# Out:
# EDUCATION  default_payment_next_month
# 0          0                                14
# 1          0                              8549
#            1                              2036
# 2          0                             10700
#            1                              3330
# 3          0                              3680
#            1                              1237
# 4          0                               116
#            1                                 7
# 5          0                               262
#            1                                18
# 6          0                                43
#            1                                 8
# Name: default_payment_next_month, dtype: int64

# %%
#Default next month and education chart
defaultgender = sns.factorplot('EDUCATION', data=credit1, hue='default_payment_next_month', kind='count', aspect=1.75)
defaultgender.set_xlabels('EDUCATION')

# %%
credit1.groupby('limit_bal_gp')['limit_bal_gp'].count()
# Out:
# limit_bal_gp
# 10000      18850
# 200000      6033
# 300000      3042
# 400000      1147
# 500000       833
# 600000        64
# 700000        28
# 800000         2
# 1000000        1
# Name: limit_bal_gp, dtype: int64

# %%
sns.factorplot('limit_bal_gp',data=credit1,kind='count',aspect=1.5)

# %%
#Default next month and limit bal gp
credit1.groupby(['limit_bal_gp','default_payment_next_month'])['default_payment_next_month'].count()
# Out:
# limit_bal_gp  default_payment_next_month
# 10000         0                             13901
#               1                              4949
# 200000        0                              5046
#               1                               987
# 300000        0                              2590
#               1                               452
# 400000        0                              1003
#               1                               144
# 500000        0                               738
#               1                                95
# 600000        0                                58
#               1                                 6
# 700000        0                                25
#               1                                 3
# 800000        0                                 2
# 1000000       0                                 1
# Name: default_payment_next_month, dtype: int64

# %%
#Default next month and limit bal gp chart
defaultgender = sns.factorplot('limit_bal_gp', data=credit1, hue='default_payment_next_month', kind='count', aspect=1.75)
defaultgender.set_xlabels('limit_bal_gp')

# %% [markdown]
# ##### Define those whose default

# %%
default_clients = credit1[credit1['default_payment_next_month']==1]

# %%
len(default_clients)
# Out:
# 6636

# %% [markdown]
# ## Client who default group by different attributes

# %%
credit1.pivot_table('default_payment_next_month','SEX','age_by_decade',aggfunc=np.sum,margins=True)
# Out:
# age_by_decade    20    30    40   50  60  70   All
# SEX
# 1               789  1050   691  295  44   4  2873
# 2              1408  1226   794  287  45   3  3763
# All            2197  2276  1485  582  89   7  6636

# %%
credit1.pivot_table('default_payment_next_month','SEX','EDUCATION',aggfunc=np.sum,margins=True)
# Out:
# EDUCATION  0     1     2     3  4   5  6   All
# SEX
# 1          0   906  1408   545  4   6  4  2873
# 2          0  1130  1922   692  3  12  4  3763
# All        0  2036  3330  1237  7  18  8  6636

# %% [markdown]
# ###### Payment Status factor - Payment status in Sep

# %%
credit1.pivot_table('default_payment_next_month','SEX','PAY_0',aggfunc=np.sum,margins=True)
# Out:
# PAY_0   -2   -1     0     1     2    3   4   5  6  7   8   All
# SEX
# 1      113  390   864   566   768  120  32   7  4  4   5  2873
# 2      252  564  1024   686  1076  124  20   6  2  3   6  3763
# All    365  954  1888  1252  1844  244  52  13  6  7  11  6636

# %%
sns.factorplot('PAY_0','default_payment_next_month', data=credit1)

# %%
sns.factorplot('PAY_0','default_payment_next_month', hue='SEX', data=credit1)

# %% [markdown]
# ###### Payment Status factor - Payment status in Aug

# %%
credit1.pivot_table('default_payment_next_month','SEX','PAY_2',aggfunc=np.sum,margins=True)
# Out:
# PAY_2     -2     -1       0    1       2      3     4     5    6     7    8  \
# SEX
# 1      246.0  379.0  1132.0  1.0   970.0   95.0  31.0   8.0  5.0   6.0  NaN
# 2      445.0  587.0  1371.0  4.0  1214.0  106.0  19.0   7.0  4.0   6.0  0.0
# All    691.0  966.0  2503.0  5.0  2184.0  201.0  50.0  15.0  9.0  12.0  0.0
#
# PAY_2   All
# SEX
# 1      2873
# 2      3763
# All    6636

# %%
sns.factorplot('PAY_2','default_payment_next_month', data=credit1)

# %%
sns.factorplot('PAY_2','default_payment_next_month', hue='EDUCATION', data=credit1)

# %%
credit1.pivot_table('default_payment_next_month','SEX','PAY_2',aggfunc=np.sum,margins=True)
# Out:
# PAY_2     -2     -1       0    1       2      3     4     5    6     7    8  \
# SEX
# 1      246.0  379.0  1132.0  1.0   970.0   95.0  31.0   8.0  5.0   6.0  NaN
# 2      445.0  587.0  1371.0  4.0  1214.0  106.0  19.0   7.0  4.0   6.0  0.0
# All    691.0  966.0  2503.0  5.0  2184.0  201.0  50.0  15.0  9.0  12.0  0.0
#
# PAY_2   All
# SEX
# 1      2873
# 2      3763
# All    6636

# %% [markdown]
# ###### Payment Status factor - Payment status in Jul

# %%
sns.factorplot('PAY_3','default_payment_next_month', data=credit1)

# %%
sns.factorplot('PAY_3','default_payment_next_month', hue='SEX', data=credit1)

# %%
credit1.pivot_table('default_payment_next_month','SEX','PAY_3',aggfunc=np.sum,margins=True)
# Out:
# PAY_3     -2     -1       0    1       2      3     4     5     6     7    8  \
# SEX
# 1      266.0  360.0  1233.0  1.0   884.0   79.0  23.0   7.0   7.0  11.0  2.0
# 2      491.0  566.0  1518.0  NaN  1085.0   59.0  21.0   5.0   7.0  11.0  NaN
# All    757.0  926.0  2751.0  1.0  1969.0  138.0  44.0  12.0  14.0  22.0  2.0
#
# PAY_3   All
# SEX
# 1      2873
# 2      3763
# All    6636

# %% [markdown]
# ###### Payment Status factor - Payment status in Jun

# %%
credit1.pivot_table('default_payment_next_month','SEX','PAY_4',aggfunc=np.sum,margins=True)
# Out:
# PAY_4     -2     -1       0    1       2      3     4     5    6     7    8  \
# SEX
# 1      314.0  347.0  1365.0  1.0   716.0   66.0  26.0   9.0  2.0  26.0  1.0
# 2      523.0  557.0  1651.0  NaN   937.0   44.0  20.0   9.0  0.0  22.0  NaN
# All    837.0  904.0  3016.0  1.0  1653.0  110.0  46.0  18.0  2.0  48.0  1.0
#
# PAY_4   All
# SEX
# 1      2873
# 2      3763
# All    6636

# %%
sns.factorplot('PAY_4','default_payment_next_month', data=credit1)

# %% [markdown]
# ######  Payment Status factor -  Payment status in May

# %%
credit1.pivot_table('default_payment_next_month','SEX','PAY_5',aggfunc=np.sum,margins=True)
# Out:
# PAY_5     -2     -1       0       2      3     4     5    6     7    8   All
# SEX
# 1      344.0  344.0  1429.0   630.0   63.0  26.0   7.0  3.0  26.0  1.0  2873
# 2      551.0  553.0  1766.0   793.0   50.0  25.0   3.0  NaN  22.0  NaN  3763
# All    895.0  897.0  3195.0  1423.0  113.0  51.0  10.0  3.0  48.0  1.0  6636

# %%
sns.factorplot('PAY_5','default_payment_next_month', data=credit1)

# %%
sns.factorplot('PAY_5','default_payment_next_month', hue='SEX', data=credit1)

# %%
sns.factorplot('PAY_5','default_payment_next_month', hue='EDUCATION', data=credit1)

# %%
sns.factorplot('PAY_5','default_payment_next_month', hue='MARRIAGE', data=credit1)

# %% [markdown]
# ###### Payment Status factor - Payment status in Apr

# %%
credit1.pivot_table('default_payment_next_month','SEX','PAY_6',aggfunc=np.sum,margins=True)
# Out:
# PAY_6     -2     -1       0       2      3     4    5     6     7    8   All
# SEX
# 1      400.0  383.0  1353.0   620.0   64.0  18.0  4.0   9.0  20.0  2.0  2873
# 2      581.0  592.0  1716.0   781.0   54.0  13.0  3.0   5.0  18.0  NaN  3763
# All    981.0  975.0  3069.0  1401.0  118.0  31.0  7.0  14.0  38.0  2.0  6636

# %%
sns.factorplot('PAY_6','default_payment_next_month', data=credit1)

# %%
sns.factorplot('PAY_6','default_payment_next_month', hue='SEX', data=credit1)

# %%
sns.factorplot('PAY_6','default_payment_next_month', hue='EDUCATION', data=credit1)

# %%
sns.factorplot('PAY_5','default_payment_next_month', hue='MARRIAGE', data=credit1)

# %% [markdown]
# ##### age factor

# %%
sns.factorplot('age_by_decade','default_payment_next_month', data=credit1)

# %% [markdown]
# ##### limit bal factor

# %%
sns.factorplot('limit_bal_gp','default_payment_next_month', data=credit1)

# %%
sns.factorplot('limit_bal_gp','default_payment_next_month', hue='SEX', data=credit1)

# %%
#linear plot default (1) vs limit bal gp
sns.lmplot('limit_bal_gp','default_payment_next_month', data=credit1)

# %%
#linear plot default (1) vs limit bal gp by sex
sns.lmplot('limit_bal_gp', 'default_payment_next_month', hue='SEX', data=credit1)

# %% [markdown]
# ##### age factor

# %%
sns.factorplot('default_payment_next_month', data=credit1, hue='age_by_decade', kind='count', 
               col='SEX')

# %%
sns.factorplot('age_by_decade','default_payment_next_month', data=credit1)

# %%
sns.factorplot('age_by_decade','default_payment_next_month', hue='SEX', data=credit1)

# %%
#linear plot default (1) vs age
sns.lmplot('age_by_decade','default_payment_next_month', data=credit1)

# %%
#linear plot default (1) vs age by sex
sns.lmplot('age_by_decade','default_payment_next_month', hue='SEX', data=credit1)

# %% [markdown]
# ##### Education factor

# %%
sns.factorplot('EDUCATION','default_payment_next_month', data=credit1)

# %%
sns.factorplot('EDUCATION','default_payment_next_month', hue='SEX', data=credit1)

# %%
sns.factorplot('EDUCATION','default_payment_next_month', hue='age_by_decade', data=credit1)

# %%
#linear plot default (1) vs edu
sns.lmplot('EDUCATION','default_payment_next_month', data=credit1)

# %%
#linear plot default (1) vs edu by sex
sns.lmplot('EDUCATION','default_payment_next_month', hue='SEX', data=credit1)

# %%
#linear plot default (1) vs edu by age
sns.lmplot('age_by_decade','default_payment_next_month', hue='EDUCATION', data=credit1)

# %% [markdown]
# ##### marriage factor

# %%
sns.factorplot('MARRIAGE','default_payment_next_month', data=credit1)

# %%
sns.factorplot('MARRIAGE','default_payment_next_month', hue='SEX', data=credit1)

# %% [markdown]
# ### Those who use revolving credit or payment delay for 2 months are likely will be default next month. Portion of female is slightly higher

# %%
table1 = pd.crosstab(index=[credit1.default_payment_next_month,credit1.age_by_decade], columns=[credit1.EDUCATION, credit1.SEX])

# %%
table1
# Out:
# EDUCATION                                 0        1           2          3  \
# SEX                                       1  2     1     2     1     2    1
# default_payment_next_month age_by_decade
# 0                          20             1  0   956  2044  1220  2382  268
#                            30             4  3  1498  2132  1565  2574  403
#                            40             3  2   705   718   862  1393  469
#                            50             0  1   241   188   281   356  262
#                            60             0  0    43    18    35    28   42
#                            70             0  0     5     1     3     1    1
# 1                          20             0  0   226   472   445   784  116
#                            30             0  0   384   443   512   626  151
#                            40             0  0   201   162   323   383  162
#                            50             0  0    80    43   108   113  103
#                            60             0  0    13    10    20    15   11
#                            70             0  0     2     0     0     1    2
#
# EDUCATION                                       4       5      6
# SEX                                         2   1   2   1   2  1   2
# default_payment_next_month age_by_decade
# 0                          20             420  17  28  26  53  4   2
#                            30             634  10  31  32  69  3   4
#                            40             725   9  16  24  33  8  12
#                            50             394   2   3   7  16  4   4
#                            60              55   0   0   0   2  2   0
#                            70               7   0   0   0   0  0   0
# 1                          20             145   2   2   0   4  0   1
#                            30             154   1   0   2   3  0   0
#                            40             240   0   1   3   5  2   3
#                            50             131   1   0   1   0  2   0
#                            60              20   0   0   0   0  0   0
#                            70               2   0   0   0   0  0   0

# %%
table.columns, table.index
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-120-969c91803a65> in <module>
# ----> 1 table.columns, table.index
#
# NameError: name 'table' is not defined

# %%
#Change column name
table1.columns.set_levels(['other0','Grad school','university','high school','other4','other5','other6'], level=0, inplace=True)
table1.columns.set_levels(['Male','Female'], level=1, inplace=True)
table1.index.set_levels(['not default next month','default next month'], level=0,inplace=True)
table1
# Out:
# EDUCATION                                other0        Grad school         \
# SEX                                        Male Female        Male Female
# default_payment_next_month age_by_decade
# not default next month     20                 1      0         956   2044
#                            30                 4      3        1498   2132
#                            40                 3      2         705    718
#                            50                 0      1         241    188
#                            60                 0      0          43     18
#                            70                 0      0           5      1
# default next month         20                 0      0         226    472
#                            30                 0      0         384    443
#                            40                 0      0         201    162
#                            50                 0      0          80     43
#                            60                 0      0          13     10
#                            70                 0      0           2      0
#
# EDUCATION                                university        high school         \
# SEX                                            Male Female        Male Female
# default_payment_next_month age_by_decade
# not default next month     20                  1220   2382         268    420
#                            30                  1565   2574         403    634
#                            40                   862   1393         469    725
#                            50                   281    356         262    394
#                            60                    35     28          42     55
#                            70                     3      1           1      7
# default next month         20                   445    784         116    145
#                            30                   512    626         151    154
#                            40                   323    383         162    240
#                            50                   108    113         103    131
#                            60                    20     15          11     20
#                            70                     0      1           2      2
#
# EDUCATION                                other4        other5        other6  \
# SEX                                        Male Female   Male Female   Male
# default_payment_next_month age_by_decade
# not default next month     20                17     28     26     53      4
#                            30                10     31     32     69      3
#                            40                 9     16     24     33      8
#                            50                 2      3      7     16      4
#                            60                 0      0      0      2      2
#                            70                 0      0      0      0      0
# default next month         20                 2      2      0      4      0
#                            30                 1      0      2      3      0
#                            40                 0      1      3      5      2
#                            50                 1      0      1      0      2
#                            60                 0      0      0      0      0
#                            70                 0      0      0      0      0
#
# EDUCATION
# SEX                                      Female
# default_payment_next_month age_by_decade
# not default next month     20                 2
#                            30                 4
#                            40                12
#                            50                 4
#                            60                 0
#                            70                 0
# default next month         20                 1
#                            30                 0
#                            40                 3
#                            50                 0
#                            60                 0
#                            70                 0

# %%
table2 = pd.crosstab(index=[credit1.default_payment_next_month,credit1.limit_bal_gp], columns=[credit1.EDUCATION, credit1.SEX])

# %%
table2
# Out:
# EDUCATION                                0        1           2           3  \
# SEX                                      1  2     1     2     1     2     1
# default_payment_next_month limit_bal_gp
# 0                          10000         3  1  1499  2328  2780  4325  1067
#                            200000        4  4   881  1477   638  1386   205
#                            300000        1  1   563   752   330   644   110
#                            400000        0  0   265   290   121   227    32
#                            500000        0  0   220   228    84   138    27
#                            600000        0  0    15    19     6     9     2
#                            700000        0  0     4     6     6     5     2
#                            800000        0  0     1     0     1     0     0
#                            1000000       0  0     0     1     0     0     0
# 1                          10000         0  0   523   683  1163  1506   471
#                            200000        0  0   199   249   156   270    46
#                            300000        0  0   110   132    60    96    15
#                            400000        0  0    38    36    22    33     8
#                            500000        0  0    33    28     6    14     5
#                            600000        0  0     2     2     1     1     0
#                            700000        0  0     1     0     0     2     0
#
# EDUCATION                                       4       5        6
# SEX                                         2   1   2   1    2   1   2
# default_payment_next_month limit_bal_gp
# 0                          10000         1656  21  30  59  102  14  16
#                            200000         341  10  30  19   45   2   4
#                            300000         147   3  12   7   16   3   1
#                            400000          52   4   1   3    6   1   1
#                            500000          31   0   4   1    4   1   0
#                            600000           7   0   0   0    0   0   0
#                            700000           1   0   1   0    0   0   0
#                            800000           0   0   0   0    0   0   0
#                            1000000          0   0   0   0    0   0   0
# 1                          10000          577   4   2   5    8   3   4
#                            200000          61   0   1   0    4   1   0
#                            300000          39   0   0   0    0   0   0
#                            400000           7   0   0   0    0   0   0
#                            500000           8   0   0   1    0   0   0
#                            600000           0   0   0   0    0   0   0
#                            700000           0   0   0   0    0   0   0

# %%
#Change column name
table2.columns.set_levels(['other0','Grad school','university','high school','other4','other5','other6'], level=0, inplace=True)
table2.columns.set_levels(['Male','Female'], level=1, inplace=True)
table2.index.set_levels(['not default next month','default next month'], level=0,inplace=True)
table2
# Out:
# EDUCATION                               other0        Grad school         \
# SEX                                       Male Female        Male Female
# default_payment_next_month limit_bal_gp
# not default next month     10000             3      1        1499   2328
#                            200000            4      4         881   1477
#                            300000            1      1         563    752
#                            400000            0      0         265    290
#                            500000            0      0         220    228
#                            600000            0      0          15     19
#                            700000            0      0           4      6
#                            800000            0      0           1      0
#                            1000000           0      0           0      1
# default next month         10000             0      0         523    683
#                            200000            0      0         199    249
#                            300000            0      0         110    132
#                            400000            0      0          38     36
#                            500000            0      0          33     28
#                            600000            0      0           2      2
#                            700000            0      0           1      0
#
# EDUCATION                               university        high school         \
# SEX                                           Male Female        Male Female
# default_payment_next_month limit_bal_gp
# not default next month     10000              2780   4325        1067   1656
#                            200000              638   1386         205    341
#                            300000              330    644         110    147
#                            400000              121    227          32     52
#                            500000               84    138          27     31
#                            600000                6      9           2      7
#                            700000                6      5           2      1
#                            800000                1      0           0      0
#                            1000000               0      0           0      0
# default next month         10000              1163   1506         471    577
#                            200000              156    270          46     61
#                            300000               60     96          15     39
#                            400000               22     33           8      7
#                            500000                6     14           5      8
#                            600000                1      1           0      0
#                            700000                0      2           0      0
#
# EDUCATION                               other4        other5        other6  \
# SEX                                       Male Female   Male Female   Male
# default_payment_next_month limit_bal_gp
# not default next month     10000            21     30     59    102     14
#                            200000           10     30     19     45      2
#                            300000            3     12      7     16      3
#                            400000            4      1      3      6      1
#                            500000            0      4      1      4      1
#                            600000            0      0      0      0      0
#                            700000            0      1      0      0      0
#                            800000            0      0      0      0      0
#                            1000000           0      0      0      0      0
# default next month         10000             4      2      5      8      3
#                            200000            0      1      0      4      1
#                            300000            0      0      0      0      0
#                            400000            0      0      0      0      0
#                            500000            0      0      1      0      0
#                            600000            0      0      0      0      0
#                            700000            0      0      0      0      0
#
# EDUCATION
# SEX                                     Female
# default_payment_next_month limit_bal_gp
# not default next month     10000            16
#                            200000            4
#                            300000            1
#                            400000            1
#                            500000            0
#                            600000            0
#                            700000            0
#                            800000            0
#                            1000000           0
# default next month         10000             4
#                            200000            0
#                            300000            0
#                            400000            0
#                            500000            0
#                            600000            0
#                            700000            0

# %%
table3 = pd.crosstab(index=[credit1.default_payment_next_month,credit1.limit_bal_gp], columns=[credit1.MARRIAGE, credit1.SEX])

# %%
table3
# Out:
# MARRIAGE                                 0         1           2         3  \
# SEX                                      1   2     1     2     1     2   1
# default_payment_next_month limit_bal_gp
# 0                          10000         8  25  1953  3699  3408  4612  74
#                            200000        2  11   873  1595   872  1667  12
#                            300000        2   1   559   790   454   772   2
#                            400000        0   0   244   290   180   285   2
#                            500000        0   0   197   216   135   189   1
#                            600000        0   0     7    12    16    23   0
#                            700000        0   0    10     6     2     7   0
#                            800000        0   0     1     0     1     0   0
#                            1000000       0   0     0     1     0     0   0
# 1                          10000         2   3   920  1330  1212  1405  35
#                            200000        0   0   230   334   169   249   3
#                            300000        0   0   113   128    71   139   1
#                            400000        0   0    45    39    23    37   0
#                            500000        0   0    34    26    10    24   1
#                            600000        0   0     3     1     0     2   0
#                            700000        0   0     1     2     0     0   0
#
# MARRIAGE
# SEX                                        2
# default_payment_next_month limit_bal_gp
# 0                          10000         122
#                            200000         14
#                            300000         10
#                            400000          2
#                            500000          0
#                            600000          0
#                            700000          0
#                            800000          0
#                            1000000         0
# 1                          10000          42
#                            200000          2
#                            300000          0
#                            400000          0
#                            500000          0
#                            600000          0
#                            700000          0

# %%
#Change column name
table3.columns.set_levels(['others','married','single','divorce'], level=0, inplace=True)
table3.columns.set_levels(['Male','Female'], level=1, inplace=True)
table3.index.set_levels(['not default next month','default next month'], level=0,inplace=True)
table3
# Out:
# MARRIAGE                                others        married        single  \
# SEX                                       Male Female    Male Female   Male
# default_payment_next_month limit_bal_gp
# not default next month     10000             8     25    1953   3699   3408
#                            200000            2     11     873   1595    872
#                            300000            2      1     559    790    454
#                            400000            0      0     244    290    180
#                            500000            0      0     197    216    135
#                            600000            0      0       7     12     16
#                            700000            0      0      10      6      2
#                            800000            0      0       1      0      1
#                            1000000           0      0       0      1      0
# default next month         10000             2      3     920   1330   1212
#                            200000            0      0     230    334    169
#                            300000            0      0     113    128     71
#                            400000            0      0      45     39     23
#                            500000            0      0      34     26     10
#                            600000            0      0       3      1      0
#                            700000            0      0       1      2      0
#
# MARRIAGE                                       divorce
# SEX                                     Female    Male Female
# default_payment_next_month limit_bal_gp
# not default next month     10000          4612      74    122
#                            200000         1667      12     14
#                            300000          772       2     10
#                            400000          285       2      2
#                            500000          189       1      0
#                            600000           23       0      0
#                            700000            7       0      0
#                            800000            0       0      0
#                            1000000           0       0      0
# default next month         10000          1405      35     42
#                            200000          249       3      2
#                            300000          139       1      0
#                            400000           37       0      0
#                            500000           24       1      0
#                            600000            2       0      0
#                            700000            0       0      0

# %%
table4 = pd.crosstab(index=[credit1.default_payment_next_month,credit1.age_by_decade], columns=[credit1.MARRIAGE, credit1.SEX])

# %%
table4
# Out:
# MARRIAGE                                  0         1           2         3  \
# SEX                                       1   2     1     2     1     2   1
# default_payment_next_month age_by_decade
# 0                          20             2   6   222   873  2260  4034   8
#                            30             5  17  1451  2855  2036  2536  23
#                            40             2  10  1470  2105   570   721  38
#                            50             3   4   598   682   176   250  20
#                            60             0   0    94    87    26    12   2
#                            70             0   0     9     7     0     2   0
# 1                          20             2   0    80   307   703  1095   4
#                            30             0   0   493   717   552   500   5
#                            40             0   3   493   584   178   193  20
#                            50             0   0   236   216    48    57  11
#                            60             0   0    40    33     4    11   0
#                            70             0   0     4     3     0     0   0
#
# MARRIAGE
# SEX                                        2
# default_payment_next_month age_by_decade
# 0                          20             16
#                            30             39
#                            40             63
#                            50             26
#                            60              4
#                            70              0
# 1                          20              6
#                            30              9
#                            40             14
#                            50             14
#                            60              1
#                            70              0

# %%
#Change column name
table4.columns.set_levels(['others','married','single','divorce'], level=0, inplace=True)
table4.columns.set_levels(['Male','Female'], level=1, inplace=True)
table4.index.set_levels(['not default next month','default next month'], level=0,inplace=True)
table4
# Out:
# MARRIAGE                                 others        married        single  \
# SEX                                        Male Female    Male Female   Male
# default_payment_next_month age_by_decade
# not default next month     20                 2      6     222    873   2260
#                            30                 5     17    1451   2855   2036
#                            40                 2     10    1470   2105    570
#                            50                 3      4     598    682    176
#                            60                 0      0      94     87     26
#                            70                 0      0       9      7      0
# default next month         20                 2      0      80    307    703
#                            30                 0      0     493    717    552
#                            40                 0      3     493    584    178
#                            50                 0      0     236    216     48
#                            60                 0      0      40     33      4
#                            70                 0      0       4      3      0
#
# MARRIAGE                                        divorce
# SEX                                      Female    Male Female
# default_payment_next_month age_by_decade
# not default next month     20              4034       8     16
#                            30              2536      23     39
#                            40               721      38     63
#                            50               250      20     26
#                            60                12       2      4
#                            70                 2       0      0
# default next month         20              1095       4      6
#                            30               500       5      9
#                            40               193      20     14
#                            50                57      11     14
#                            60                11       0      1
#                            70                 0       0      0

# %%
table5 = pd.crosstab(index=[credit1.default_payment_next_month,credit1.limit_bal_gp], columns=[credit1.SEX, credit1.PAY_5])

# %%
table5
# Out:
# SEX                                        1                                \
# PAY_5                                     -2   -1     0    2   3   4  5  6
# default_payment_next_month limit_bal_gp
# 0                          10000         567  759  3643  418  33  17  1  0
#                            200000        340  460   899   58   0   2  0  0
#                            300000        233  284   480   19   0   0  0  1
#                            400000         76  104   238    8   0   0  0  0
#                            500000         46  106   175    5   0   1  0  0
#                            600000          4    2    16    1   0   0  0  0
#                            700000          3    2     7    0   0   0  0  0
#                            800000          0    1     1    0   0   0  0  0
#                            1000000         0    0     0    0   0   0  0  0
# 1                          10000         174  205  1155  518  60  24  5  3
#                            200000         72   83   158   83   1   2  1  0
#                            300000         72   29    65   19   0   0  0  0
#                            400000         13   15    32    5   2   0  1  0
#                            500000         13   12    15    5   0   0  0  0
#                            600000          0    0     3    0   0   0  0  0
#                            700000          0    0     1    0   0   0  0  0
#
# SEX                                                2                           \
# PAY_5                                     7  8    -2    -1     0    2   3   4
# default_payment_next_month limit_bal_gp
# 0                          10000          5  0  1064  1461  5311  569  30  12
#                            200000         0  0   709   837  1654   84   2   1
#                            300000         0  0   383   374   783   33   0   0
#                            400000         0  0   126   164   283    4   0   0
#                            500000         0  0    89    78   234    4   0   0
#                            600000         0  0     7     7    21    0   0   0
#                            700000         0  0     4     3     6    0   0   0
#                            800000         0  0     0     0     0    0   0   0
#                            1000000        0  0     0     0     1    0   0   0
# 1                          10000         24  1   276   316  1401  699  43  22
#                            200000         2  0   131   159   220   69   5   1
#                            300000         0  0   109    49    86   19   1   1
#                            400000         0  0    20    18    33    4   1   0
#                            500000         0  0    15     9    24    1   0   1
#                            600000         0  0     0     1     2    0   0   0
#                            700000         0  0     0     1     0    1   0   0
#
# SEX
# PAY_5                                    5   7
# default_payment_next_month limit_bal_gp
# 0                          10000         6   5
#                            200000        0   0
#                            300000        0   0
#                            400000        0   0
#                            500000        0   0
#                            600000        0   0
#                            700000        0   0
#                            800000        0   0
#                            1000000       0   0
# 1                          10000         3  20
#                            200000        0   0
#                            300000        0   2
#                            400000        0   0
#                            500000        0   0
#                            600000        0   0
#                            700000        0   0

# %%
#Change column name
table5.columns.set_levels(['Male','Female'], level=0, inplace=True)
table5.columns.set_levels(['no consumpt','paid in full','use credit','delay 1mth','delay 2mth', 'delay 3mth', 'delay 4mth', 'delay 5mth', 'delay 6mth','delay 7 mth'], level=1, inplace=True)
table5.index.set_levels(['not default next month','default next month'], level=0,inplace=True)
table5
# Out:
# SEX                                            Male                          \
# PAY_5                                   no consumpt paid in full use credit
# default_payment_next_month limit_bal_gp
# not default next month     10000                567          759       3643
#                            200000               340          460        899
#                            300000               233          284        480
#                            400000                76          104        238
#                            500000                46          106        175
#                            600000                 4            2         16
#                            700000                 3            2          7
#                            800000                 0            1          1
#                            1000000                0            0          0
# default next month         10000                174          205       1155
#                            200000                72           83        158
#                            300000                72           29         65
#                            400000                13           15         32
#                            500000                13           12         15
#                            600000                 0            0          3
#                            700000                 0            0          1
#
# SEX                                                                       \
# PAY_5                                   delay 1mth delay 2mth delay 3mth
# default_payment_next_month limit_bal_gp
# not default next month     10000               418         33         17
#                            200000               58          0          2
#                            300000               19          0          0
#                            400000                8          0          0
#                            500000                5          0          1
#                            600000                1          0          0
#                            700000                0          0          0
#                            800000                0          0          0
#                            1000000               0          0          0
# default next month         10000               518         60         24
#                            200000               83          1          2
#                            300000               19          0          0
#                            400000                5          2          0
#                            500000                5          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#
# SEX                                                                       \
# PAY_5                                   delay 4mth delay 5mth delay 6mth
# default_payment_next_month limit_bal_gp
# not default next month     10000                 1          0          5
#                            200000                0          0          0
#                            300000                0          1          0
#                            400000                0          0          0
#                            500000                0          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#                            800000                0          0          0
#                            1000000               0          0          0
# default next month         10000                 5          3         24
#                            200000                1          0          2
#                            300000                0          0          0
#                            400000                1          0          0
#                            500000                0          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#
# SEX                                                      Female               \
# PAY_5                                   delay 7 mth no consumpt paid in full
# default_payment_next_month limit_bal_gp
# not default next month     10000                  0        1064         1461
#                            200000                 0         709          837
#                            300000                 0         383          374
#                            400000                 0         126          164
#                            500000                 0          89           78
#                            600000                 0           7            7
#                            700000                 0           4            3
#                            800000                 0           0            0
#                            1000000                0           0            0
# default next month         10000                  1         276          316
#                            200000                 0         131          159
#                            300000                 0         109           49
#                            400000                 0          20           18
#                            500000                 0          15            9
#                            600000                 0           0            1
#                            700000                 0           0            1
#
# SEX                                                                       \
# PAY_5                                   use credit delay 1mth delay 2mth
# default_payment_next_month limit_bal_gp
# not default next month     10000              5311        569         30
#                            200000             1654         84          2
#                            300000              783         33          0
#                            400000              283          4          0
#                            500000              234          4          0
#                            600000               21          0          0
#                            700000                6          0          0
#                            800000                0          0          0
#                            1000000               1          0          0
# default next month         10000              1401        699         43
#                            200000              220         69          5
#                            300000               86         19          1
#                            400000               33          4          1
#                            500000               24          1          0
#                            600000                2          0          0
#                            700000                0          1          0
#
# SEX
# PAY_5                                   delay 3mth delay 4mth delay 6mth
# default_payment_next_month limit_bal_gp
# not default next month     10000                12          6          5
#                            200000                1          0          0
#                            300000                0          0          0
#                            400000                0          0          0
#                            500000                0          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#                            800000                0          0          0
#                            1000000               0          0          0
# default next month         10000                22          3         20
#                            200000                1          0          0
#                            300000                1          0          2
#                            400000                0          0          0
#                            500000                1          0          0
#                            600000                0          0          0
#                            700000                0          0          0

# %%
table6 = pd.crosstab(index=[credit1.default_payment_next_month,credit1.limit_bal_gp], columns=[credit1.SEX, credit1.PAY_6])

# %%
table6
# Out:
# SEX                                        1                                \
# PAY_6                                     -2   -1     0    2   3   4  5  6
# default_payment_next_month limit_bal_gp
# 0                          10000         680  782  3490  448  30   5  3  2
#                            200000        353  446   883   74   1   2  0  0
#                            300000        243  295   458   20   0   0  1  0
#                            400000         78  100   236   12   0   0  0  0
#                            500000         53  108   167    4   0   0  0  1
#                            600000          5    1    17    0   0   0  0  0
#                            700000          3    1     8    0   0   0  0  0
#                            800000          0    2     0    0   0   0  0  0
#                            1000000         0    0     0    0   0   0  0  0
# 1                          10000         225  240  1088  507  62  16  3  8
#                            200000         72   86   155   83   1   2  0  1
#                            300000         74   31    62   18   0   0  0  0
#                            400000         15   16    30    5   1   0  1  0
#                            500000         14   10    14    7   0   0  0  0
#                            600000          0    0     3    0   0   0  0  0
#                            700000          0    0     1    0   0   0  0  0
#
# SEX                                                2                           \
# PAY_6                                     7  8    -2    -1     0    2   3   4
# default_payment_next_month limit_bal_gp
# 0                          10000          3  0  1171  1480  5088  673  28  10
#                            200000         0  0   727   847  1617   89   5   1
#                            300000         0  0   388   420   728   36   1   0
#                            400000         0  0   117   171   285    4   0   0
#                            500000         0  0    86   100   213    5   1   0
#                            600000         0  0     7     7    21    0   0   0
#                            700000         0  0     3     5     5    0   0   0
#                            800000         0  0     0     0     0    0   0   0
#                            1000000        0  0     0     0     1    0   0   0
# 1                          10000         18  2   301   338  1362  696  46  13
#                            200000         2  0   139   164   215   63   4   0
#                            300000         0  0   105    58    82   18   2   0
#                            400000         0  0    20    21    30    4   1   0
#                            500000         0  0    16    10    23    0   1   0
#                            600000         0  0     0     0     3    0   0   0
#                            700000         0  0     0     1     1    0   0   0
#
# SEX
# PAY_6                                    5  6   7
# default_payment_next_month limit_bal_gp
# 0                          10000         2  1   5
#                            200000        0  1   0
#                            300000        0  0   0
#                            400000        0  0   0
#                            500000        0  0   0
#                            600000        0  0   0
#                            700000        0  0   0
#                            800000        0  0   0
#                            1000000       0  0   0
# 1                          10000         3  5  16
#                            200000        0  0   0
#                            300000        0  0   2
#                            400000        0  0   0
#                            500000        0  0   0
#                            600000        0  0   0
#                            700000        0  0   0

# %%
#Change column name
table6.columns.set_levels(['Male','Female'], level=0, inplace=True)
table6.columns.set_levels(['no consumpt','paid in full','use credit','delay 1mth','delay 2mth', 'delay 3mth', 'delay 4mth', 'delay 5mth', 'delay 6mth','delay 7 mth'], level=1, inplace=True)
table6.index.set_levels(['not default next month','default next month'], level=0,inplace=True)
table6
# Out:
# SEX                                            Male                          \
# PAY_6                                   no consumpt paid in full use credit
# default_payment_next_month limit_bal_gp
# not default next month     10000                680          782       3490
#                            200000               353          446        883
#                            300000               243          295        458
#                            400000                78          100        236
#                            500000                53          108        167
#                            600000                 5            1         17
#                            700000                 3            1          8
#                            800000                 0            2          0
#                            1000000                0            0          0
# default next month         10000                225          240       1088
#                            200000                72           86        155
#                            300000                74           31         62
#                            400000                15           16         30
#                            500000                14           10         14
#                            600000                 0            0          3
#                            700000                 0            0          1
#
# SEX                                                                       \
# PAY_6                                   delay 1mth delay 2mth delay 3mth
# default_payment_next_month limit_bal_gp
# not default next month     10000               448         30          5
#                            200000               74          1          2
#                            300000               20          0          0
#                            400000               12          0          0
#                            500000                4          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#                            800000                0          0          0
#                            1000000               0          0          0
# default next month         10000               507         62         16
#                            200000               83          1          2
#                            300000               18          0          0
#                            400000                5          1          0
#                            500000                7          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#
# SEX                                                                       \
# PAY_6                                   delay 4mth delay 5mth delay 6mth
# default_payment_next_month limit_bal_gp
# not default next month     10000                 3          2          3
#                            200000                0          0          0
#                            300000                1          0          0
#                            400000                0          0          0
#                            500000                0          1          0
#                            600000                0          0          0
#                            700000                0          0          0
#                            800000                0          0          0
#                            1000000               0          0          0
# default next month         10000                 3          8         18
#                            200000                0          1          2
#                            300000                0          0          0
#                            400000                1          0          0
#                            500000                0          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#
# SEX                                                      Female               \
# PAY_6                                   delay 7 mth no consumpt paid in full
# default_payment_next_month limit_bal_gp
# not default next month     10000                  0        1171         1480
#                            200000                 0         727          847
#                            300000                 0         388          420
#                            400000                 0         117          171
#                            500000                 0          86          100
#                            600000                 0           7            7
#                            700000                 0           3            5
#                            800000                 0           0            0
#                            1000000                0           0            0
# default next month         10000                  2         301          338
#                            200000                 0         139          164
#                            300000                 0         105           58
#                            400000                 0          20           21
#                            500000                 0          16           10
#                            600000                 0           0            0
#                            700000                 0           0            1
#
# SEX                                                                       \
# PAY_6                                   use credit delay 1mth delay 2mth
# default_payment_next_month limit_bal_gp
# not default next month     10000              5088        673         28
#                            200000             1617         89          5
#                            300000              728         36          1
#                            400000              285          4          0
#                            500000              213          5          1
#                            600000               21          0          0
#                            700000                5          0          0
#                            800000                0          0          0
#                            1000000               1          0          0
# default next month         10000              1362        696         46
#                            200000              215         63          4
#                            300000               82         18          2
#                            400000               30          4          1
#                            500000               23          0          1
#                            600000                3          0          0
#                            700000                1          0          0
#
# SEX                                                                       \
# PAY_6                                   delay 3mth delay 4mth delay 5mth
# default_payment_next_month limit_bal_gp
# not default next month     10000                10          2          1
#                            200000                1          0          1
#                            300000                0          0          0
#                            400000                0          0          0
#                            500000                0          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#                            800000                0          0          0
#                            1000000               0          0          0
# default next month         10000                13          3          5
#                            200000                0          0          0
#                            300000                0          0          0
#                            400000                0          0          0
#                            500000                0          0          0
#                            600000                0          0          0
#                            700000                0          0          0
#
# SEX
# PAY_6                                   delay 6mth
# default_payment_next_month limit_bal_gp
# not default next month     10000                 5
#                            200000                0
#                            300000                0
#                            400000                0
#                            500000                0
#                            600000                0
#                            700000                0
#                            800000                0
#                            1000000               0
# default next month         10000                16
#                            200000                0
#                            300000                2
#                            400000                0
#                            500000                0
#                            600000                0
#                            700000                0

# %%
table7 = pd.crosstab(index=[credit1.default_payment_next_month,credit1.age_by_decade], columns=[credit1.SEX, credit1.PAY_5])
table7
# Out:
# SEX                                         1                                \
# PAY_5                                      -2   -1     0    2   3   4  5  6
# default_payment_next_month age_by_decade
# 0                          20             307  378  1622  165  10   9  0  0
#                            30             544  735  2024  196   7   5  1  1
#                            40             305  424  1229  108  11   1  0  0
#                            50              99  153   504   33   5   3  0  0
#                            60              14   27    72    7   0   2  0  0
#                            70               0    1     8    0   0   0  0  0
# 1                          20              73   78   412  179  25  11  1  2
#                            30             131  132   513  235  16   8  2  1
#                            40              84  101   349  131  15   5  3  0
#                            50              44   25   139   74   6   2  1  0
#                            60              10    8    16    9   1   0  0  0
#                            70               2    0     0    2   0   0  0  0
#
# SEX                                                 2                       \
# PAY_5                                      7  8    -2    -1     0    2   3
# default_payment_next_month age_by_decade
# 0                          20              1  0   576   867  3158  305  10
#                            30              2  0  1033  1178  3001  222  11
#                            40              2  0   578   665  1533  114   4
#                            50              0  0   176   194   533   50   7
#                            60              0  0    17    18    63    3   0
#                            70              0  0     2     2     5    0   0
# 1                          20              8  0   147   147   754  315  22
#                            30             12  0   220   239   508  242   8
#                            40              2  1   124   121   356  171  11
#                            50              4  0    46    39   127   60   9
#                            60              0  0    12     7    20    5   0
#                            70              0  0     2     0     1    0   0
#
# SEX
# PAY_5                                      4  5  7
# default_payment_next_month age_by_decade
# 0                          20              5  5  3
#                            30              1  1  0
#                            40              3  0  2
#                            50              2  0  0
#                            60              2  0  0
#                            70              0  0  0
# 1                          20             14  1  8
#                            30              4  1  4
#                            40              6  1  4
#                            50              1  0  5
#                            60              0  0  1
#                            70              0  0  0

# %%
#Change column name
table7.columns.set_levels(['Male','Female'], level=0, inplace=True)
table7.columns.set_levels(['no consumpt','paid in full','use credit','delay 1mth','delay 2mth', 'delay 3mth', 'delay 4mth', 'delay 5mth', 'delay 6mth','delay 7 mth'], level=1, inplace=True)
table7.index.set_levels(['not default next month','default next month'], level=0,inplace=True)
table7
# Out:
# SEX                                             Male                          \
# PAY_5                                    no consumpt paid in full use credit
# default_payment_next_month age_by_decade
# not default next month     20                    307          378       1622
#                            30                    544          735       2024
#                            40                    305          424       1229
#                            50                     99          153        504
#                            60                     14           27         72
#                            70                      0            1          8
# default next month         20                     73           78        412
#                            30                    131          132        513
#                            40                     84          101        349
#                            50                     44           25        139
#                            60                     10            8         16
#                            70                      2            0          0
#
# SEX                                                                        \
# PAY_5                                    delay 1mth delay 2mth delay 3mth
# default_payment_next_month age_by_decade
# not default next month     20                   165         10          9
#                            30                   196          7          5
#                            40                   108         11          1
#                            50                    33          5          3
#                            60                     7          0          2
#                            70                     0          0          0
# default next month         20                   179         25         11
#                            30                   235         16          8
#                            40                   131         15          5
#                            50                    74          6          2
#                            60                     9          1          0
#                            70                     2          0          0
#
# SEX                                                                        \
# PAY_5                                    delay 4mth delay 5mth delay 6mth
# default_payment_next_month age_by_decade
# not default next month     20                     0          0          1
#                            30                     1          1          2
#                            40                     0          0          2
#                            50                     0          0          0
#                            60                     0          0          0
#                            70                     0          0          0
# default next month         20                     1          2          8
#                            30                     2          1         12
#                            40                     3          0          2
#                            50                     1          0          4
#                            60                     0          0          0
#                            70                     0          0          0
#
# SEX                                                       Female               \
# PAY_5                                    delay 7 mth no consumpt paid in full
# default_payment_next_month age_by_decade
# not default next month     20                      0         576          867
#                            30                      0        1033         1178
#                            40                      0         578          665
#                            50                      0         176          194
#                            60                      0          17           18
#                            70                      0           2            2
# default next month         20                      0         147          147
#                            30                      0         220          239
#                            40                      1         124          121
#                            50                      0          46           39
#                            60                      0          12            7
#                            70                      0           2            0
#
# SEX                                                                        \
# PAY_5                                    use credit delay 1mth delay 2mth
# default_payment_next_month age_by_decade
# not default next month     20                  3158        305         10
#                            30                  3001        222         11
#                            40                  1533        114          4
#                            50                   533         50          7
#                            60                    63          3          0
#                            70                     5          0          0
# default next month         20                   754        315         22
#                            30                   508        242          8
#                            40                   356        171         11
#                            50                   127         60          9
#                            60                    20          5          0
#                            70                     1          0          0
#
# SEX
# PAY_5                                    delay 3mth delay 4mth delay 6mth
# default_payment_next_month age_by_decade
# not default next month     20                     5          5          3
#                            30                     1          1          0
#                            40                     3          0          2
#                            50                     2          0          0
#                            60                     2          0          0
#                            70                     0          0          0
# default next month         20                    14          1          8
#                            30                     4          1          4
#                            40                     6          1          4
#                            50                     1          0          5
#                            60                     0          0          1
#                            70                     0          0          0

# %%
table8 = pd.crosstab(index=[credit1.default_payment_next_month,credit1.age_by_decade], columns=[credit1.SEX, credit1.PAY_6])
table8
# Out:
# SEX                                         1                                \
# PAY_6                                      -2   -1     0    2   3   4  5  6
# default_payment_next_month age_by_decade
# 0                          20             357  391  1547  177  14   3  2  1
#                            30             597  729  1964  212   8   2  1  1
#                            40             339  424  1191  117   5   1  1  0
#                            50             107  160   483   43   4   0  0  0
#                            60              15   31    66    8   0   1  0  1
#                            70               0    0     8    1   0   0  0  0
# 1                          20              90   84   390  179  25  11  1  4
#                            30             156  142   479  236  21   1  3  2
#                            40              97  112   332  129  13   3  0  2
#                            50              46   36   136   65   5   2  0  1
#                            60               9    9    16    9   0   1  0  0
#                            70               2    0     0    2   0   0  0  0
#
# SEX                                                2                          \
# PAY_6                                     7  8    -2    -1     0    2   3  4
# default_payment_next_month age_by_decade
# 0                          20             0  0   660   860  3040  343  13  9
#                            30             1  0  1058  1251  2855  271   9  1
#                            40             2  0   588   706  1469  126   8  0
#                            50             0  0   173   195   528   61   4  0
#                            60             0  0    17    16    62    6   1  1
#                            70             0  0     3     2     4    0   0  0
# 1                          20             5  0   167   174   720  307  26  6
#                            30             9  1   225   238   509  235  12  1
#                            40             2  1   128   132   344  167  14  3
#                            50             4  0    47    40   122   69   1  3
#                            60             0  0    12     8    20    3   1  0
#                            70             0  0     2     0     1    0   0  0
#
# SEX
# PAY_6                                     5  6  7
# default_payment_next_month age_by_decade
# 0                          20             0  1  3
#                            30             1  1  0
#                            40             0  0  2
#                            50             1  0  0
#                            60             0  0  0
#                            70             0  0  0
# 1                          20             0  3  5
#                            30             1  1  4
#                            40             2  1  3
#                            50             0  0  5
#                            60             0  0  1
#                            70             0  0  0

# %%
#Change column name
table8.columns.set_levels(['Male','Female'], level=0, inplace=True)
table8.columns.set_levels(['no consumpt','paid in full','use credit','delay 1mth','delay 2mth', 'delay 3mth', 'delay 4mth', 'delay 5mth', 'delay 6mth','delay 7 mth'], level=1, inplace=True)
table8.index.set_levels(['not default next month','default next month'], level=0,inplace=True)
table8
# Out:
# SEX                                             Male                          \
# PAY_6                                    no consumpt paid in full use credit
# default_payment_next_month age_by_decade
# not default next month     20                    357          391       1547
#                            30                    597          729       1964
#                            40                    339          424       1191
#                            50                    107          160        483
#                            60                     15           31         66
#                            70                      0            0          8
# default next month         20                     90           84        390
#                            30                    156          142        479
#                            40                     97          112        332
#                            50                     46           36        136
#                            60                      9            9         16
#                            70                      2            0          0
#
# SEX                                                                        \
# PAY_6                                    delay 1mth delay 2mth delay 3mth
# default_payment_next_month age_by_decade
# not default next month     20                   177         14          3
#                            30                   212          8          2
#                            40                   117          5          1
#                            50                    43          4          0
#                            60                     8          0          1
#                            70                     1          0          0
# default next month         20                   179         25         11
#                            30                   236         21          1
#                            40                   129         13          3
#                            50                    65          5          2
#                            60                     9          0          1
#                            70                     2          0          0
#
# SEX                                                                        \
# PAY_6                                    delay 4mth delay 5mth delay 6mth
# default_payment_next_month age_by_decade
# not default next month     20                     2          1          0
#                            30                     1          1          1
#                            40                     1          0          2
#                            50                     0          0          0
#                            60                     0          1          0
#                            70                     0          0          0
# default next month         20                     1          4          5
#                            30                     3          2          9
#                            40                     0          2          2
#                            50                     0          1          4
#                            60                     0          0          0
#                            70                     0          0          0
#
# SEX                                                       Female               \
# PAY_6                                    delay 7 mth no consumpt paid in full
# default_payment_next_month age_by_decade
# not default next month     20                      0         660          860
#                            30                      0        1058         1251
#                            40                      0         588          706
#                            50                      0         173          195
#                            60                      0          17           16
#                            70                      0           3            2
# default next month         20                      0         167          174
#                            30                      1         225          238
#                            40                      1         128          132
#                            50                      0          47           40
#                            60                      0          12            8
#                            70                      0           2            0
#
# SEX                                                                        \
# PAY_6                                    use credit delay 1mth delay 2mth
# default_payment_next_month age_by_decade
# not default next month     20                  3040        343         13
#                            30                  2855        271          9
#                            40                  1469        126          8
#                            50                   528         61          4
#                            60                    62          6          1
#                            70                     4          0          0
# default next month         20                   720        307         26
#                            30                   509        235         12
#                            40                   344        167         14
#                            50                   122         69          1
#                            60                    20          3          1
#                            70                     1          0          0
#
# SEX                                                                        \
# PAY_6                                    delay 3mth delay 4mth delay 5mth
# default_payment_next_month age_by_decade
# not default next month     20                     9          0          1
#                            30                     1          1          1
#                            40                     0          0          0
#                            50                     0          1          0
#                            60                     1          0          0
#                            70                     0          0          0
# default next month         20                     6          0          3
#                            30                     1          1          1
#                            40                     3          2          1
#                            50                     3          0          0
#                            60                     0          0          0
#                            70                     0          0          0
#
# SEX
# PAY_6                                    delay 6mth
# default_payment_next_month age_by_decade
# not default next month     20                     3
#                            30                     0
#                            40                     2
#                            50                     0
#                            60                     0
#                            70                     0
# default next month         20                     5
#                            30                     4
#                            40                     3
#                            50                     5
#                            60                     1
#                            70                     0

# %%
import pandas_profiling as pp
import os

# %%
credit1profile=ProfileReport(credit1, title='Credit1 Report',html={'style':{'full_width':True}})
# Out:
# HBox(children=(FloatProgress(value=0.0, description='variables', max=28.0, style=ProgressStyle(description_wid…
# HBox(children=(FloatProgress(value=0.0, description='correlations', max=6.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='interactions [continuous]', max=529.0, style=ProgressStyl…
# HBox(children=(FloatProgress(value=0.0, description='table', max=1.0, style=ProgressStyle(description_width='i…
# HBox(children=(FloatProgress(value=0.0, description='missing', max=2.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='warnings', max=3.0, style=ProgressStyle(description_width…
# HBox(children=(FloatProgress(value=0.0, description='package', max=1.0, style=ProgressStyle(description_width=…
# HBox(children=(FloatProgress(value=0.0, description='build report structure', max=1.0, style=ProgressStyle(des…

# %%
credit1profile.to_file(output_file = "credit1_report.html")
